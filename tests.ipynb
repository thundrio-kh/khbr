# %%
from khbr.randomizer import KingdomHearts2
import random, os, json, time

kh2 = KingdomHearts2()
bosses = kh2.get_bosses()


# Fake number right now
MAXCACHESIZE = 25_000_00_000_000#FAKE NUMBER # A little under Shan yu's max size, just a guess for right now
UNLIMITEDSIZE = 99_999_999_999_999
SOLUTIONSWANTED = 10

# A few bosses can be found in multiple spawnpoints, ignore the ones that don't matter
# to make a list of bosses with 1 spawnpoint each

outdir = os.path.join("khbr", "randomizations")
# Two option
options = {"name": "limited", "size": MAXCACHESIZE}

print(options)
bosses = kh2.get_bosses(maxsize=options["size"], stable_only=stableonly)
    
bosses_base = list(bosses.keys())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-db58ec2f3c91> in <module>()
#       2 import random, os, json, time
#       3
# ----> 4 kh2 = KingdomHearts2()
#       5 bosses = kh2.get_bosses()
#       6
#
# ~/khbr/khbr/randomizer.py in __init__(self)
#      70         with open(os.path.join(os.path.dirname(__file__), "msns.json")) as f:
#      71             self.msninfo = json.load(f)
# ---> 72         self.enemy_records = self.get_bosses(usefilters=False, getavail=False)
#      73     def get_valid_enemies(self):
#      74         return [b for b in self.enemy_records if self.enemy_records[b]["type"] == "enemy"]
#
# ~/khbr/khbr/randomizer.py in get_bosses(self, nightmare_mode, maxsize, usefilters, getavail)
#     140             b = bosses_f[bn]
#     141             for v in b["variations"]:
# --> 142                 boss = dict(b["variations"][v])
#     143                 boss["name"] = v
#     144                 for k in b:
#
# ValueError: dictionary update sequence element #0 has length 3; 2 is required

# %%
sorted(bosses)
# Out:
# ['Armor Xemnas I',
#  'Armor Xemnas II',
#  'Axel I',
#  'Axel II',
#  'Blizzard Lord',
#  'Blizzard Lord (Cups)',
#  'Cerberus',
#  'Cerberus (1)',
#  'Cloud',
#  'Cloud (1)',
#  'Cloud (2)',
#  'Dark Thorn',
#  'Data Axel',
#  'Data Demyx',
#  'Data Luxord',
#  'Data Saix',
#  'Data Xaldin',
#  'Data Xemnas',
#  'Data Xigbar',
#  'Demyx',
#  'Grim Reaper I',
#  'Hades Cups',
#  'Hercules',
#  'Hostile Program',
#  'Larxene',
#  'Larxene (Data)',
#  'Leon',
#  'Leon (1)',
#  'Leon (2)',
#  'Leon (3)',
#  'Lexaeus',
#  'Lexaeus (Data)',
#  'Luxord',
#  'Marluxia',
#  'Marluxia (Data)',
#  'Past Pete',
#  'Pete Cups',
#  'Pete OC II',
#  'Prison Keeper',
#  'Roxas',
#  'Roxas (Data)',
#  'Saix',
#  'Sark',
#  'Scar',
#  'Sephiroth',
#  'Shan-Yu',
#  'Storm Rider',
#  'Terra',
#  'The Experiment',
#  'Tifa',
#  'Tifa (1)',
#  'Tifa (2)',
#  'Twilight Thorn',
#  'Vexen',
#  'Vexen (1)',
#  'Volcano Lord',
#  'Volcano Lord (Cups)',
#  'Xaldin',
#  'Xemnas',
#  'Xigbar',
#  'Yuffie',
#  'Yuffie (1)',
#  'Yuffie (2)',
#  'Yuffie (3)',
#  'Zexion',
#  'Zexion (Data)']

# %%
for boss in sorted(bosses, key=lambda k: len(bosses[k]["available"])):
    print("{}-{}".format(boss, len(bosses[boss]["available"])))
# Out:
# ['Storm Rider', 'Terra']
# Storm Rider-2
# Hostile Program-42
# Saix-42
# Demyx-42
# Vexen-42
# Vexen (1)-42
# Lexaeus (Data)-42
# Lexaeus-42
# Zexion (Data)-42
# Zexion-42
# Data Saix-42
# Data Luxord-42
# Luxord-42
# Xigbar-57
# Data Xigbar-57
# Grim Reaper I-66
# Blizzard Lord-66
# Blizzard Lord (Cups)-66
# Volcano Lord-66
# Volcano Lord (Cups)-66
# Shan-Yu-66
# Twilight Thorn-66
# Xemnas-66
# Past Pete-66
# Axel II-66
# Armor Xemnas II-66
# Armor Xemnas I-66
# Scar-66
# Axel I-66
# Sephiroth-66
# Pete OC II-66
# Sark-66
# Leon-66
# Leon (1)-66
# Leon (2)-66
# Leon (3)-66
# Cloud-66
# Cloud (1)-66
# Cloud (2)-66
# Tifa-66
# Tifa (1)-66
# Tifa (2)-66
# Yuffie-66
# Yuffie (1)-66
# Yuffie (2)-66
# Yuffie (3)-66
# Hades Cups-66
# Pete Cups-66
# Hercules-66
# Marluxia (Data)-66
# Marluxia-66
# Roxas-66
# Roxas (Data)-66
# Cerberus-66
# Cerberus (1)-66
# Dark Thorn-66
# Larxene (Data)-66
# Larxene-66
# Terra-66
# Data Axel-66
# Data Xemnas-66
# Data Xaldin-66
# Data Demyx-66
# Prison Keeper-66
# The Experiment-66
# Xaldin-66

# %%
    solutions = []
    start_time = time.time()
    while len(solutions) < SOLUTIONSWANTED:
        possible_solution = list(bosses_base)
        random.shuffle(possible_solution)
    
        solution_found = True
        for b in range(len(possible_solution)):
            if not possible_solution[b] in bosses[bosses_base[b]]["available"]:
                solution_found = False
                break
        
        if solution_found:
            length = int(time.time() - start_time)
            start_time = time.time()
            print(solution_found, len(solutions), "{}s".format(length))
            solutions.append({bosses_base[i]:possible_solution[i] for i in range(len(possible_solution))})    

    for i in range(len(solutions)):
        fn = os.path.join(outdir, options["name"], str(i))
        if not os.path.isdir(os.path.dirname(fn)):
            os.makedirs(os.path.dirname(fn))
        json.dump(solutions[i], open(fn, "w"))
