# %%
from khbr.randomizer import KingdomHearts2
import random, os, json, time

kh2 = KingdomHearts2()
bosses = kh2.get_bosses()


# Fake number right now
MAXCACHESIZE = 16.8#FAKE NUMBER # A little under Shan yu's max size, just a guess for right now
UNLIMITEDSIZE = 99_999_999_999_999
SOLUTIONSWANTED = 10

# A few bosses can be found in multiple spawnpoints, ignore the ones that don't matter
# to make a list of bosses with 1 spawnpoint each

outdir = os.path.join("khbr", "randomizations")
# Two option
options = {"name": "limited", "size": MAXCACHESIZE}

print(options)
bosses = kh2.get_bosses(maxsize=options["size"])
    
bosses_base = list(bosses.keys())
# Out:
# Armor Xemnas II > Armor Xemnas I: 1.7 + 12.98 >= 99999999999999
# Armor Xemnas II > Axel I: 1.7 + 9.43 >= 99999999999999
# Armor Xemnas II > Axel II: 1.7 + 3.68 >= 99999999999999
# Armor Xemnas II > Blizzard Lord: 1.7 + 10.32 >= 99999999999999
# Armor Xemnas II > Blizzard Lord (Cups): 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Cerberus: 1.7 + 10.54 >= 99999999999999
# Armor Xemnas II > Cerberus (Cups): 1.7 + 0 >= 99999999999999
# Armor Xemnas II > Cloud: 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Cloud (1): 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Cloud (2): 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Dark Thorn: 1.7 + 11.1 >= 99999999999999
# Armor Xemnas II > Demyx: 1.7 + 10.62 >= 99999999999999
# Armor Xemnas II > Grim Reaper I: 1.7 + 12.61 >= 99999999999999
# Armor Xemnas II > Groundshaker: 1.7 + 6.15 >= 99999999999999
# Armor Xemnas II > Hades Cups: 1.7 + 0 >= 99999999999999
# Armor Xemnas II > Hades II: 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Hades II (1): 1.7 + 0 >= 99999999999999
# Armor Xemnas II > Hercules: 1.7 + 0 >= 99999999999999
# Armor Xemnas II > Hostile Program: 1.7 + 9.16 >= 99999999999999
# Armor Xemnas II > Hydra: 1.7 + 10.22 >= 99999999999999
# Armor Xemnas II > Larxene: 1.7 + 8.3 >= 99999999999999
# Armor Xemnas II > Leon: 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Leon (1): 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Leon (2): 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Leon (3): 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Lexaeus: 1.7 + 8.36 >= 99999999999999
# Armor Xemnas II > Luxord: 1.7 + 7.25 >= 99999999999999
# Armor Xemnas II > Marluxia: 1.7 + 7.96 >= 99999999999999
# Armor Xemnas II > Past Pete: 1.7 + 11.16 >= 99999999999999
# Armor Xemnas II > Pete Cups: 1.7 + 0 >= 99999999999999
# Armor Xemnas II > Pete OC II: 1.7 + 13.53 >= 99999999999999
# Armor Xemnas II > Pete TR: 1.7 + 12.16 >= 99999999999999
# Armor Xemnas II > Prison Keeper: 1.7 + 9.21 >= 99999999999999
# Armor Xemnas II > Roxas: 1.7 + 5.83 >= 99999999999999
# Armor Xemnas II > Saix: 1.7 + 10.3 >= 99999999999999
# Armor Xemnas II > Sark: 1.7 + 9.9 >= 99999999999999
# Armor Xemnas II > Scar: 1.7 + 6.34 >= 99999999999999
# Armor Xemnas II > Sephiroth: 1.7 + 6.57 >= 99999999999999
# Armor Xemnas II > Shan-Yu: 1.7 + 10.15 >= 99999999999999
# Armor Xemnas II > Storm Rider: 1.7 + 9.27 >= 99999999999999
# Armor Xemnas II > The Experiment: 1.7 + 11.7 >= 99999999999999
# Armor Xemnas II > Tifa: 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Tifa (1): 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Tifa (2): 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Twilight Thorn: 1.7 + 3.93 >= 99999999999999
# Armor Xemnas II > Vexen: 1.7 + 8.97 >= 99999999999999
# Armor Xemnas II > Volcano Lord: 1.7 + 10.32 >= 99999999999999
# Armor Xemnas II > Volcano Lord (Cups): 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Xaldin: 1.7 + 9.61 >= 99999999999999
# Armor Xemnas II > Xemnas: 1.7 + 6.16 >= 99999999999999
# Armor Xemnas II > Xigbar: 1.7 + 11.18 >= 99999999999999
# Armor Xemnas II > Yuffie: 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Yuffie (1): 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Yuffie (2): 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Yuffie (3): 1.7 + 9.14 >= 99999999999999
# Armor Xemnas II > Zexion: 1.7 + 9.14 >= 99999999999999
# Armor Xemnas I > Armor Xemnas II: 3.82 + 9.23 >= 99999999999999
# Armor Xemnas I > Axel I: 3.82 + 9.43 >= 99999999999999
# Armor Xemnas I > Axel II: 3.82 + 3.68 >= 99999999999999
# Armor Xemnas I > Blizzard Lord: 3.82 + 10.32 >= 99999999999999
# Armor Xemnas I > Blizzard Lord (Cups): 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Cerberus: 3.82 + 10.54 >= 99999999999999
# Armor Xemnas I > Cerberus (Cups): 3.82 + 0 >= 99999999999999
# Armor Xemnas I > Cloud: 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Cloud (1): 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Cloud (2): 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Dark Thorn: 3.82 + 11.1 >= 99999999999999
# Armor Xemnas I > Demyx: 3.82 + 10.62 >= 99999999999999
# Armor Xemnas I > Grim Reaper I: 3.82 + 12.61 >= 99999999999999
# Armor Xemnas I > Groundshaker: 3.82 + 6.15 >= 99999999999999
# Armor Xemnas I > Hades Cups: 3.82 + 0 >= 99999999999999
# Armor Xemnas I > Hades II: 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Hades II (1): 3.82 + 0 >= 99999999999999
# Armor Xemnas I > Hercules: 3.82 + 0 >= 99999999999999
# Armor Xemnas I > Hostile Program: 3.82 + 9.16 >= 99999999999999
# Armor Xemnas I > Hydra: 3.82 + 10.22 >= 99999999999999
# Armor Xemnas I > Larxene: 3.82 + 8.3 >= 99999999999999
# Armor Xemnas I > Leon: 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Leon (1): 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Leon (2): 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Leon (3): 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Lexaeus: 3.82 + 8.36 >= 99999999999999
# Armor Xemnas I > Luxord: 3.82 + 7.25 >= 99999999999999
# Armor Xemnas I > Marluxia: 3.82 + 7.96 >= 99999999999999
# Armor Xemnas I > Past Pete: 3.82 + 11.16 >= 99999999999999
# Armor Xemnas I > Pete Cups: 3.82 + 0 >= 99999999999999
# Armor Xemnas I > Pete OC II: 3.82 + 13.53 >= 99999999999999
# Armor Xemnas I > Pete TR: 3.82 + 12.16 >= 99999999999999
# Armor Xemnas I > Prison Keeper: 3.82 + 9.21 >= 99999999999999
# Armor Xemnas I > Roxas: 3.82 + 5.83 >= 99999999999999
# Armor Xemnas I > Saix: 3.82 + 10.3 >= 99999999999999
# Armor Xemnas I > Sark: 3.82 + 9.9 >= 99999999999999
# Armor Xemnas I > Scar: 3.82 + 6.34 >= 99999999999999
# Armor Xemnas I > Sephiroth: 3.82 + 6.57 >= 99999999999999
# Armor Xemnas I > Shan-Yu: 3.82 + 10.15 >= 99999999999999
# Armor Xemnas I > Storm Rider: 3.82 + 9.27 >= 99999999999999
# Armor Xemnas I > The Experiment: 3.82 + 11.7 >= 99999999999999
# Armor Xemnas I > Tifa: 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Tifa (1): 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Tifa (2): 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Twilight Thorn: 3.82 + 3.93 >= 99999999999999
# Armor Xemnas I > Vexen: 3.82 + 8.97 >= 99999999999999
# Armor Xemnas I > Volcano Lord: 3.82 + 10.32 >= 99999999999999
# Armor Xemnas I > Volcano Lord (Cups): 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Xaldin: 3.82 + 9.61 >= 99999999999999
# Armor Xemnas I > Xemnas: 3.82 + 6.16 >= 99999999999999
# Armor Xemnas I > Xigbar: 3.82 + 11.18 >= 99999999999999
# Armor Xemnas I > Yuffie: 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Yuffie (1): 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Yuffie (2): 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Yuffie (3): 3.82 + 9.14 >= 99999999999999
# Armor Xemnas I > Zexion: 3.82 + 9.14 >= 99999999999999
# Axel I > Armor Xemnas II: 2.92 + 9.23 >= 99999999999999
# Axel I > Armor Xemnas I: 2.92 + 12.98 >= 99999999999999
# Axel I > Axel II: 2.92 + 3.68 >= 99999999999999
# Axel I > Blizzard Lord: 2.92 + 10.32 >= 99999999999999
# Axel I > Blizzard Lord (Cups): 2.92 + 9.14 >= 99999999999999
# Axel I > Cerberus: 2.92 + 10.54 >= 99999999999999
# Axel I > Cerberus (Cups): 2.92 + 0 >= 99999999999999
# Axel I > Cloud: 2.92 + 9.14 >= 99999999999999
# Axel I > Cloud (1): 2.92 + 9.14 >= 99999999999999
# Axel I > Cloud (2): 2.92 + 9.14 >= 99999999999999
# Axel I > Dark Thorn: 2.92 + 11.1 >= 99999999999999
# Axel I > Demyx: 2.92 + 10.62 >= 99999999999999
# Axel I > Grim Reaper I: 2.92 + 12.61 >= 99999999999999
# Axel I > Groundshaker: 2.92 + 6.15 >= 99999999999999
# Axel I > Hades Cups: 2.92 + 0 >= 99999999999999
# Axel I > Hades II: 2.92 + 9.14 >= 99999999999999
# Axel I > Hades II (1): 2.92 + 0 >= 99999999999999
# Axel I > Hercules: 2.92 + 0 >= 99999999999999
# Axel I > Hostile Program: 2.92 + 9.16 >= 99999999999999
# Axel I > Hydra: 2.92 + 10.22 >= 99999999999999
# Axel I > Larxene: 2.92 + 8.3 >= 99999999999999
# Axel I > Leon: 2.92 + 9.14 >= 99999999999999
# Axel I > Leon (1): 2.92 + 9.14 >= 99999999999999
# Axel I > Leon (2): 2.92 + 9.14 >= 99999999999999
# Axel I > Leon (3): 2.92 + 9.14 >= 99999999999999
# Axel I > Lexaeus: 2.92 + 8.36 >= 99999999999999
# Axel I > Luxord: 2.92 + 7.25 >= 99999999999999
# Axel I > Marluxia: 2.92 + 7.96 >= 99999999999999
# Axel I > Past Pete: 2.92 + 11.16 >= 99999999999999
# Axel I > Pete Cups: 2.92 + 0 >= 99999999999999
# Axel I > Pete OC II: 2.92 + 13.53 >= 99999999999999
# Axel I > Pete TR: 2.92 + 12.16 >= 99999999999999
# Axel I > Prison Keeper: 2.92 + 9.21 >= 99999999999999
# Axel I > Roxas: 2.92 + 5.83 >= 99999999999999
# Axel I > Saix: 2.92 + 10.3 >= 99999999999999
# Axel I > Sark: 2.92 + 9.9 >= 99999999999999
# Axel I > Scar: 2.92 + 6.34 >= 99999999999999
# Axel I > Sephiroth: 2.92 + 6.57 >= 99999999999999
# Axel I > Shan-Yu: 2.92 + 10.15 >= 99999999999999
# Axel I > Storm Rider: 2.92 + 9.27 >= 99999999999999
# Axel I > The Experiment: 2.92 + 11.7 >= 99999999999999
# Axel I > Tifa: 2.92 + 9.14 >= 99999999999999
# Axel I > Tifa (1): 2.92 + 9.14 >= 99999999999999
# Axel I > Tifa (2): 2.92 + 9.14 >= 99999999999999
# Axel I > Twilight Thorn: 2.92 + 3.93 >= 99999999999999
# Axel I > Vexen: 2.92 + 8.97 >= 99999999999999
# Axel I > Volcano Lord: 2.92 + 10.32 >= 99999999999999
# Axel I > Volcano Lord (Cups): 2.92 + 9.14 >= 99999999999999
# Axel I > Xaldin: 2.92 + 9.61 >= 99999999999999
# Axel I > Xemnas: 2.92 + 6.16 >= 99999999999999
# Axel I > Xigbar: 2.92 + 11.18 >= 99999999999999
# Axel I > Yuffie: 2.92 + 9.14 >= 99999999999999
# Axel I > Yuffie (1): 2.92 + 9.14 >= 99999999999999
# Axel I > Yuffie (2): 2.92 + 9.14 >= 99999999999999
# Axel I > Yuffie (3): 2.92 + 9.14 >= 99999999999999
# Axel I > Zexion: 2.92 + 9.14 >= 99999999999999
# Axel II > Armor Xemnas I: 3.74 + 12.98 >= 99999999999999
# Axel II > Blizzard Lord: 3.74 + 10.32 >= 99999999999999
# Axel II > Blizzard Lord (Cups): 3.74 + 9.14 >= 99999999999999
# Axel II > Cerberus: 3.74 + 10.54 >= 99999999999999
# Axel II > Cerberus (Cups): 3.74 + 0 >= 99999999999999
# Axel II > Cloud: 3.74 + 9.14 >= 99999999999999
# Axel II > Cloud (1): 3.74 + 9.14 >= 99999999999999
# Axel II > Cloud (2): 3.74 + 9.14 >= 99999999999999
# Axel II > Dark Thorn: 3.74 + 11.1 >= 99999999999999
# Axel II > Demyx: 3.74 + 10.62 >= 99999999999999
# Axel II > Grim Reaper I: 3.74 + 12.61 >= 99999999999999
# Axel II > Hades Cups: 3.74 + 0 >= 99999999999999
# Axel II > Hades II: 3.74 + 9.14 >= 99999999999999
# Axel II > Hades II (1): 3.74 + 0 >= 99999999999999
# Axel II > Hercules: 3.74 + 0 >= 99999999999999
# Axel II > Hostile Program: 3.74 + 9.16 >= 99999999999999
# Axel II > Hydra: 3.74 + 10.22 >= 99999999999999
# Axel II > Larxene: 3.74 + 8.3 >= 99999999999999
# Axel II > Leon: 3.74 + 9.14 >= 99999999999999
# Axel II > Leon (1): 3.74 + 9.14 >= 99999999999999
# Axel II > Leon (2): 3.74 + 9.14 >= 99999999999999
# Axel II > Leon (3): 3.74 + 9.14 >= 99999999999999
# Axel II > Lexaeus: 3.74 + 8.36 >= 99999999999999
# Axel II > Luxord: 3.74 + 7.25 >= 99999999999999
# Axel II > Marluxia: 3.74 + 7.96 >= 99999999999999
# Axel II > Pete Cups: 3.74 + 0 >= 99999999999999
# Axel II > Pete OC II: 3.74 + 13.53 >= 99999999999999
# Axel II > Pete TR: 3.74 + 12.16 >= 99999999999999
# Axel II > Roxas: 3.74 + 5.83 >= 99999999999999
# Axel II > Saix: 3.74 + 10.3 >= 99999999999999
# Axel II > Sark: 3.74 + 9.9 >= 99999999999999
# Axel II > Scar: 3.74 + 6.34 >= 99999999999999
# Axel II > Sephiroth: 3.74 + 6.57 >= 99999999999999
# Axel II > Shan-Yu: 3.74 + 10.15 >= 99999999999999
# Axel II > Storm Rider: 3.74 + 9.27 >= 99999999999999
# Axel II > The Experiment: 3.74 + 11.7 >= 99999999999999
# Axel II > Tifa: 3.74 + 9.14 >= 99999999999999
# Axel II > Tifa (1): 3.74 + 9.14 >= 99999999999999
# Axel II > Tifa (2): 3.74 + 9.14 >= 99999999999999
# Axel II > Vexen: 3.74 + 8.97 >= 99999999999999
# Axel II > Volcano Lord: 3.74 + 10.32 >= 99999999999999
# Axel II > Volcano Lord (Cups): 3.74 + 9.14 >= 99999999999999
# Axel II > Xaldin: 3.74 + 9.61 >= 99999999999999
# Axel II > Xemnas: 3.74 + 6.16 >= 99999999999999
# Axel II > Xigbar: 3.74 + 11.18 >= 99999999999999
# Axel II > Yuffie: 3.74 + 9.14 >= 99999999999999
# Axel II > Yuffie (1): 3.74 + 9.14 >= 99999999999999
# Axel II > Yuffie (2): 3.74 + 9.14 >= 99999999999999
# Axel II > Yuffie (3): 3.74 + 9.14 >= 99999999999999
# Axel II > Zexion: 3.74 + 9.14 >= 99999999999999
# Blizzard Lord > Armor Xemnas II: 2.58 + 9.23 >= 99999999999999
# Blizzard Lord > Armor Xemnas I: 2.58 + 12.98 >= 99999999999999
# Blizzard Lord > Axel I: 2.58 + 9.43 >= 99999999999999
# Blizzard Lord > Axel II: 2.58 + 3.68 >= 99999999999999
# Blizzard Lord > Blizzard Lord (Cups): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Cerberus: 2.58 + 10.54 >= 99999999999999
# Blizzard Lord > Cerberus (Cups): 2.58 + 0 >= 99999999999999
# Blizzard Lord > Cloud: 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Cloud (1): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Cloud (2): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Dark Thorn: 2.58 + 11.1 >= 99999999999999
# Blizzard Lord > Demyx: 2.58 + 10.62 >= 99999999999999
# Blizzard Lord > Grim Reaper I: 2.58 + 12.61 >= 99999999999999
# Blizzard Lord > Groundshaker: 2.58 + 6.15 >= 99999999999999
# Blizzard Lord > Hades Cups: 2.58 + 0 >= 99999999999999
# Blizzard Lord > Hades II: 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Hades II (1): 2.58 + 0 >= 99999999999999
# Blizzard Lord > Hercules: 2.58 + 0 >= 99999999999999
# Blizzard Lord > Hostile Program: 2.58 + 9.16 >= 99999999999999
# Blizzard Lord > Hydra: 2.58 + 10.22 >= 99999999999999
# Blizzard Lord > Larxene: 2.58 + 8.3 >= 99999999999999
# Blizzard Lord > Leon: 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Leon (1): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Leon (2): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Leon (3): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Lexaeus: 2.58 + 8.36 >= 99999999999999
# Blizzard Lord > Luxord: 2.58 + 7.25 >= 99999999999999
# Blizzard Lord > Marluxia: 2.58 + 7.96 >= 99999999999999
# Blizzard Lord > Past Pete: 2.58 + 11.16 >= 99999999999999
# Blizzard Lord > Pete Cups: 2.58 + 0 >= 99999999999999
# Blizzard Lord > Pete OC II: 2.58 + 13.53 >= 99999999999999
# Blizzard Lord > Pete TR: 2.58 + 12.16 >= 99999999999999
# Blizzard Lord > Prison Keeper: 2.58 + 9.21 >= 99999999999999
# Blizzard Lord > Roxas: 2.58 + 5.83 >= 99999999999999
# Blizzard Lord > Saix: 2.58 + 10.3 >= 99999999999999
# Blizzard Lord > Sark: 2.58 + 9.9 >= 99999999999999
# Blizzard Lord > Scar: 2.58 + 6.34 >= 99999999999999
# Blizzard Lord > Sephiroth: 2.58 + 6.57 >= 99999999999999
# Blizzard Lord > Shan-Yu: 2.58 + 10.15 >= 99999999999999
# Blizzard Lord > Storm Rider: 2.58 + 9.27 >= 99999999999999
# Blizzard Lord > The Experiment: 2.58 + 11.7 >= 99999999999999
# Blizzard Lord > Tifa: 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Tifa (1): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Tifa (2): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Twilight Thorn: 2.58 + 3.93 >= 99999999999999
# Blizzard Lord > Vexen: 2.58 + 8.97 >= 99999999999999
# Blizzard Lord > Volcano Lord: 2.58 + 10.32 >= 99999999999999
# Blizzard Lord > Volcano Lord (Cups): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Xaldin: 2.58 + 9.61 >= 99999999999999
# Blizzard Lord > Xemnas: 2.58 + 6.16 >= 99999999999999
# Blizzard Lord > Xigbar: 2.58 + 11.18 >= 99999999999999
# Blizzard Lord > Yuffie: 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Yuffie (1): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Yuffie (2): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Yuffie (3): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord > Zexion: 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Armor Xemnas II: 2.58 + 9.23 >= 99999999999999
# Blizzard Lord (Cups) > Armor Xemnas I: 2.58 + 12.98 >= 99999999999999
# Blizzard Lord (Cups) > Axel I: 2.58 + 9.43 >= 99999999999999
# Blizzard Lord (Cups) > Axel II: 2.58 + 3.68 >= 99999999999999
# Blizzard Lord (Cups) > Blizzard Lord: 2.58 + 10.32 >= 99999999999999
# Blizzard Lord (Cups) > Cerberus: 2.58 + 10.54 >= 99999999999999
# Blizzard Lord (Cups) > Cerberus (Cups): 2.58 + 0 >= 99999999999999
# Blizzard Lord (Cups) > Cloud: 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Cloud (1): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Cloud (2): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Dark Thorn: 2.58 + 11.1 >= 99999999999999
# Blizzard Lord (Cups) > Demyx: 2.58 + 10.62 >= 99999999999999
# Blizzard Lord (Cups) > Grim Reaper I: 2.58 + 12.61 >= 99999999999999
# Blizzard Lord (Cups) > Groundshaker: 2.58 + 6.15 >= 99999999999999
# Blizzard Lord (Cups) > Hades Cups: 2.58 + 0 >= 99999999999999
# Blizzard Lord (Cups) > Hades II: 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Hades II (1): 2.58 + 0 >= 99999999999999
# Blizzard Lord (Cups) > Hercules: 2.58 + 0 >= 99999999999999
# Blizzard Lord (Cups) > Hostile Program: 2.58 + 9.16 >= 99999999999999
# Blizzard Lord (Cups) > Hydra: 2.58 + 10.22 >= 99999999999999
# Blizzard Lord (Cups) > Larxene: 2.58 + 8.3 >= 99999999999999
# Blizzard Lord (Cups) > Leon: 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Leon (1): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Leon (2): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Leon (3): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Lexaeus: 2.58 + 8.36 >= 99999999999999
# Blizzard Lord (Cups) > Luxord: 2.58 + 7.25 >= 99999999999999
# Blizzard Lord (Cups) > Marluxia: 2.58 + 7.96 >= 99999999999999
# Blizzard Lord (Cups) > Past Pete: 2.58 + 11.16 >= 99999999999999
# Blizzard Lord (Cups) > Pete Cups: 2.58 + 0 >= 99999999999999
# Blizzard Lord (Cups) > Pete OC II: 2.58 + 13.53 >= 99999999999999
# Blizzard Lord (Cups) > Pete TR: 2.58 + 12.16 >= 99999999999999
# Blizzard Lord (Cups) > Prison Keeper: 2.58 + 9.21 >= 99999999999999
# Blizzard Lord (Cups) > Roxas: 2.58 + 5.83 >= 99999999999999
# Blizzard Lord (Cups) > Saix: 2.58 + 10.3 >= 99999999999999
# Blizzard Lord (Cups) > Sark: 2.58 + 9.9 >= 99999999999999
# Blizzard Lord (Cups) > Scar: 2.58 + 6.34 >= 99999999999999
# Blizzard Lord (Cups) > Sephiroth: 2.58 + 6.57 >= 99999999999999
# Blizzard Lord (Cups) > Shan-Yu: 2.58 + 10.15 >= 99999999999999
# Blizzard Lord (Cups) > Storm Rider: 2.58 + 9.27 >= 99999999999999
# Blizzard Lord (Cups) > The Experiment: 2.58 + 11.7 >= 99999999999999
# Blizzard Lord (Cups) > Tifa: 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Tifa (1): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Tifa (2): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Twilight Thorn: 2.58 + 3.93 >= 99999999999999
# Blizzard Lord (Cups) > Vexen: 2.58 + 8.97 >= 99999999999999
# Blizzard Lord (Cups) > Volcano Lord: 2.58 + 10.32 >= 99999999999999
# Blizzard Lord (Cups) > Volcano Lord (Cups): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Xaldin: 2.58 + 9.61 >= 99999999999999
# Blizzard Lord (Cups) > Xemnas: 2.58 + 6.16 >= 99999999999999
# Blizzard Lord (Cups) > Xigbar: 2.58 + 11.18 >= 99999999999999
# Blizzard Lord (Cups) > Yuffie: 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Yuffie (1): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Yuffie (2): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Yuffie (3): 2.58 + 9.14 >= 99999999999999
# Blizzard Lord (Cups) > Zexion: 2.58 + 9.14 >= 99999999999999
# Cerberus > Armor Xemnas II: 3.2 + 9.23 >= 99999999999999
# Cerberus > Armor Xemnas I: 3.2 + 12.98 >= 99999999999999
# Cerberus > Axel I: 3.2 + 9.43 >= 99999999999999
# Cerberus > Axel II: 3.2 + 3.68 >= 99999999999999
# Cerberus > Blizzard Lord: 3.2 + 10.32 >= 99999999999999
# Cerberus > Blizzard Lord (Cups): 3.2 + 9.14 >= 99999999999999
# Cerberus > Cerberus (Cups): 3.2 + 0 >= 99999999999999
# Cerberus > Cloud: 3.2 + 9.14 >= 99999999999999
# Cerberus > Cloud (1): 3.2 + 9.14 >= 99999999999999
# Cerberus > Cloud (2): 3.2 + 9.14 >= 99999999999999
# Cerberus > Dark Thorn: 3.2 + 11.1 >= 99999999999999
# Cerberus > Demyx: 3.2 + 10.62 >= 99999999999999
# Cerberus > Grim Reaper I: 3.2 + 12.61 >= 99999999999999
# Cerberus > Groundshaker: 3.2 + 6.15 >= 99999999999999
# Cerberus > Hades Cups: 3.2 + 0 >= 99999999999999
# Cerberus > Hades II: 3.2 + 9.14 >= 99999999999999
# Cerberus > Hades II (1): 3.2 + 0 >= 99999999999999
# Cerberus > Hercules: 3.2 + 0 >= 99999999999999
# Cerberus > Hostile Program: 3.2 + 9.16 >= 99999999999999
# Cerberus > Hydra: 3.2 + 10.22 >= 99999999999999
# Cerberus > Larxene: 3.2 + 8.3 >= 99999999999999
# Cerberus > Leon: 3.2 + 9.14 >= 99999999999999
# Cerberus > Leon (1): 3.2 + 9.14 >= 99999999999999
# Cerberus > Leon (2): 3.2 + 9.14 >= 99999999999999
# Cerberus > Leon (3): 3.2 + 9.14 >= 99999999999999
# Cerberus > Lexaeus: 3.2 + 8.36 >= 99999999999999
# Cerberus > Luxord: 3.2 + 7.25 >= 99999999999999
# Cerberus > Marluxia: 3.2 + 7.96 >= 99999999999999
# Cerberus > Past Pete: 3.2 + 11.16 >= 99999999999999
# Cerberus > Pete Cups: 3.2 + 0 >= 99999999999999
# Cerberus > Pete OC II: 3.2 + 13.53 >= 99999999999999
# Cerberus > Pete TR: 3.2 + 12.16 >= 99999999999999
# Cerberus > Prison Keeper: 3.2 + 9.21 >= 99999999999999
# Cerberus > Roxas: 3.2 + 5.83 >= 99999999999999
# Cerberus > Saix: 3.2 + 10.3 >= 99999999999999
# Cerberus > Sark: 3.2 + 9.9 >= 99999999999999
# Cerberus > Scar: 3.2 + 6.34 >= 99999999999999
# Cerberus > Sephiroth: 3.2 + 6.57 >= 99999999999999
# Cerberus > Shan-Yu: 3.2 + 10.15 >= 99999999999999
# Cerberus > Storm Rider: 3.2 + 9.27 >= 99999999999999
# Cerberus > The Experiment: 3.2 + 11.7 >= 99999999999999
# Cerberus > Tifa: 3.2 + 9.14 >= 99999999999999
# Cerberus > Tifa (1): 3.2 + 9.14 >= 99999999999999
# Cerberus > Tifa (2): 3.2 + 9.14 >= 99999999999999
# Cerberus > Twilight Thorn: 3.2 + 3.93 >= 99999999999999
# Cerberus > Vexen: 3.2 + 8.97 >= 99999999999999
# Cerberus > Volcano Lord: 3.2 + 10.32 >= 99999999999999
# Cerberus > Volcano Lord (Cups): 3.2 + 9.14 >= 99999999999999
# Cerberus > Xaldin: 3.2 + 9.61 >= 99999999999999
# Cerberus > Xemnas: 3.2 + 6.16 >= 99999999999999
# Cerberus > Xigbar: 3.2 + 11.18 >= 99999999999999
# Cerberus > Yuffie: 3.2 + 9.14 >= 99999999999999
# Cerberus > Yuffie (1): 3.2 + 9.14 >= 99999999999999
# Cerberus > Yuffie (2): 3.2 + 9.14 >= 99999999999999
# Cerberus > Yuffie (3): 3.2 + 9.14 >= 99999999999999
# Cerberus > Zexion: 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Armor Xemnas II: 3.2 + 9.23 >= 99999999999999
# Cerberus (Cups) > Armor Xemnas I: 3.2 + 12.98 >= 99999999999999
# Cerberus (Cups) > Axel I: 3.2 + 9.43 >= 99999999999999
# Cerberus (Cups) > Axel II: 3.2 + 3.68 >= 99999999999999
# Cerberus (Cups) > Blizzard Lord: 3.2 + 10.32 >= 99999999999999
# Cerberus (Cups) > Blizzard Lord (Cups): 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Cerberus: 3.2 + 10.54 >= 99999999999999
# Cerberus (Cups) > Cloud: 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Cloud (1): 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Cloud (2): 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Dark Thorn: 3.2 + 11.1 >= 99999999999999
# Cerberus (Cups) > Demyx: 3.2 + 10.62 >= 99999999999999
# Cerberus (Cups) > Grim Reaper I: 3.2 + 12.61 >= 99999999999999
# Cerberus (Cups) > Groundshaker: 3.2 + 6.15 >= 99999999999999
# Cerberus (Cups) > Hades Cups: 3.2 + 0 >= 99999999999999
# Cerberus (Cups) > Hades II: 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Hades II (1): 3.2 + 0 >= 99999999999999
# Cerberus (Cups) > Hercules: 3.2 + 0 >= 99999999999999
# Cerberus (Cups) > Hostile Program: 3.2 + 9.16 >= 99999999999999
# Cerberus (Cups) > Hydra: 3.2 + 10.22 >= 99999999999999
# Cerberus (Cups) > Larxene: 3.2 + 8.3 >= 99999999999999
# Cerberus (Cups) > Leon: 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Leon (1): 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Leon (2): 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Leon (3): 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Lexaeus: 3.2 + 8.36 >= 99999999999999
# Cerberus (Cups) > Luxord: 3.2 + 7.25 >= 99999999999999
# Cerberus (Cups) > Marluxia: 3.2 + 7.96 >= 99999999999999
# Cerberus (Cups) > Past Pete: 3.2 + 11.16 >= 99999999999999
# Cerberus (Cups) > Pete Cups: 3.2 + 0 >= 99999999999999
# Cerberus (Cups) > Pete OC II: 3.2 + 13.53 >= 99999999999999
# Cerberus (Cups) > Pete TR: 3.2 + 12.16 >= 99999999999999
# Cerberus (Cups) > Prison Keeper: 3.2 + 9.21 >= 99999999999999
# Cerberus (Cups) > Roxas: 3.2 + 5.83 >= 99999999999999
# Cerberus (Cups) > Saix: 3.2 + 10.3 >= 99999999999999
# Cerberus (Cups) > Sark: 3.2 + 9.9 >= 99999999999999
# Cerberus (Cups) > Scar: 3.2 + 6.34 >= 99999999999999
# Cerberus (Cups) > Sephiroth: 3.2 + 6.57 >= 99999999999999
# Cerberus (Cups) > Shan-Yu: 3.2 + 10.15 >= 99999999999999
# Cerberus (Cups) > Storm Rider: 3.2 + 9.27 >= 99999999999999
# Cerberus (Cups) > The Experiment: 3.2 + 11.7 >= 99999999999999
# Cerberus (Cups) > Tifa: 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Tifa (1): 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Tifa (2): 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Twilight Thorn: 3.2 + 3.93 >= 99999999999999
# Cerberus (Cups) > Vexen: 3.2 + 8.97 >= 99999999999999
# Cerberus (Cups) > Volcano Lord: 3.2 + 10.32 >= 99999999999999
# Cerberus (Cups) > Volcano Lord (Cups): 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Xaldin: 3.2 + 9.61 >= 99999999999999
# Cerberus (Cups) > Xemnas: 3.2 + 6.16 >= 99999999999999
# Cerberus (Cups) > Xigbar: 3.2 + 11.18 >= 99999999999999
# Cerberus (Cups) > Yuffie: 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Yuffie (1): 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Yuffie (2): 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Yuffie (3): 3.2 + 9.14 >= 99999999999999
# Cerberus (Cups) > Zexion: 3.2 + 9.14 >= 99999999999999
# Cloud > Armor Xemnas II: 1.9 + 9.23 >= 99999999999999
# Cloud > Armor Xemnas I: 1.9 + 12.98 >= 99999999999999
# Cloud > Axel I: 1.9 + 9.43 >= 99999999999999
# Cloud > Axel II: 1.9 + 3.68 >= 99999999999999
# Cloud > Blizzard Lord: 1.9 + 10.32 >= 99999999999999
# Cloud > Blizzard Lord (Cups): 1.9 + 9.14 >= 99999999999999
# Cloud > Cerberus: 1.9 + 10.54 >= 99999999999999
# Cloud > Cerberus (Cups): 1.9 + 0 >= 99999999999999
# Cloud > Cloud (1): 1.9 + 9.14 >= 99999999999999
# Cloud > Cloud (2): 1.9 + 9.14 >= 99999999999999
# Cloud > Dark Thorn: 1.9 + 11.1 >= 99999999999999
# Cloud > Demyx: 1.9 + 10.62 >= 99999999999999
# Cloud > Grim Reaper I: 1.9 + 12.61 >= 99999999999999
# Cloud > Groundshaker: 1.9 + 6.15 >= 99999999999999
# Cloud > Hades Cups: 1.9 + 0 >= 99999999999999
# Cloud > Hades II: 1.9 + 9.14 >= 99999999999999
# Cloud > Hades II (1): 1.9 + 0 >= 99999999999999
# Cloud > Hercules: 1.9 + 0 >= 99999999999999
# Cloud > Hostile Program: 1.9 + 9.16 >= 99999999999999
# Cloud > Hydra: 1.9 + 10.22 >= 99999999999999
# Cloud > Larxene: 1.9 + 8.3 >= 99999999999999
# Cloud > Leon: 1.9 + 9.14 >= 99999999999999
# Cloud > Leon (1): 1.9 + 9.14 >= 99999999999999
# Cloud > Leon (2): 1.9 + 9.14 >= 99999999999999
# Cloud > Leon (3): 1.9 + 9.14 >= 99999999999999
# Cloud > Lexaeus: 1.9 + 8.36 >= 99999999999999
# Cloud > Luxord: 1.9 + 7.25 >= 99999999999999
# Cloud > Marluxia: 1.9 + 7.96 >= 99999999999999
# Cloud > Past Pete: 1.9 + 11.16 >= 99999999999999
# Cloud > Pete Cups: 1.9 + 0 >= 99999999999999
# Cloud > Pete OC II: 1.9 + 13.53 >= 99999999999999
# Cloud > Pete TR: 1.9 + 12.16 >= 99999999999999
# Cloud > Prison Keeper: 1.9 + 9.21 >= 99999999999999
# Cloud > Roxas: 1.9 + 5.83 >= 99999999999999
# Cloud > Saix: 1.9 + 10.3 >= 99999999999999
# Cloud > Sark: 1.9 + 9.9 >= 99999999999999
# Cloud > Scar: 1.9 + 6.34 >= 99999999999999
# Cloud > Sephiroth: 1.9 + 6.57 >= 99999999999999
# Cloud > Shan-Yu: 1.9 + 10.15 >= 99999999999999
# Cloud > Storm Rider: 1.9 + 9.27 >= 99999999999999
# Cloud > The Experiment: 1.9 + 11.7 >= 99999999999999
# Cloud > Tifa: 1.9 + 9.14 >= 99999999999999
# Cloud > Tifa (1): 1.9 + 9.14 >= 99999999999999
# Cloud > Tifa (2): 1.9 + 9.14 >= 99999999999999
# Cloud > Twilight Thorn: 1.9 + 3.93 >= 99999999999999
# Cloud > Vexen: 1.9 + 8.97 >= 99999999999999
# Cloud > Volcano Lord: 1.9 + 10.32 >= 99999999999999
# Cloud > Volcano Lord (Cups): 1.9 + 9.14 >= 99999999999999
# Cloud > Xaldin: 1.9 + 9.61 >= 99999999999999
# Cloud > Xemnas: 1.9 + 6.16 >= 99999999999999
# Cloud > Xigbar: 1.9 + 11.18 >= 99999999999999
# Cloud > Yuffie: 1.9 + 9.14 >= 99999999999999
# Cloud > Yuffie (1): 1.9 + 9.14 >= 99999999999999
# Cloud > Yuffie (2): 1.9 + 9.14 >= 99999999999999
# Cloud > Yuffie (3): 1.9 + 9.14 >= 99999999999999
# Cloud > Zexion: 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Armor Xemnas II: 1.9 + 9.23 >= 99999999999999
# Cloud (1) > Armor Xemnas I: 1.9 + 12.98 >= 99999999999999
# Cloud (1) > Axel I: 1.9 + 9.43 >= 99999999999999
# Cloud (1) > Axel II: 1.9 + 3.68 >= 99999999999999
# Cloud (1) > Blizzard Lord: 1.9 + 10.32 >= 99999999999999
# Cloud (1) > Blizzard Lord (Cups): 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Cerberus: 1.9 + 10.54 >= 99999999999999
# Cloud (1) > Cerberus (Cups): 1.9 + 0 >= 99999999999999
# Cloud (1) > Cloud: 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Cloud (2): 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Dark Thorn: 1.9 + 11.1 >= 99999999999999
# Cloud (1) > Demyx: 1.9 + 10.62 >= 99999999999999
# Cloud (1) > Grim Reaper I: 1.9 + 12.61 >= 99999999999999
# Cloud (1) > Groundshaker: 1.9 + 6.15 >= 99999999999999
# Cloud (1) > Hades Cups: 1.9 + 0 >= 99999999999999
# Cloud (1) > Hades II: 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Hades II (1): 1.9 + 0 >= 99999999999999
# Cloud (1) > Hercules: 1.9 + 0 >= 99999999999999
# Cloud (1) > Hostile Program: 1.9 + 9.16 >= 99999999999999
# Cloud (1) > Hydra: 1.9 + 10.22 >= 99999999999999
# Cloud (1) > Larxene: 1.9 + 8.3 >= 99999999999999
# Cloud (1) > Leon: 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Leon (1): 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Leon (2): 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Leon (3): 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Lexaeus: 1.9 + 8.36 >= 99999999999999
# Cloud (1) > Luxord: 1.9 + 7.25 >= 99999999999999
# Cloud (1) > Marluxia: 1.9 + 7.96 >= 99999999999999
# Cloud (1) > Past Pete: 1.9 + 11.16 >= 99999999999999
# Cloud (1) > Pete Cups: 1.9 + 0 >= 99999999999999
# Cloud (1) > Pete OC II: 1.9 + 13.53 >= 99999999999999
# Cloud (1) > Pete TR: 1.9 + 12.16 >= 99999999999999
# Cloud (1) > Prison Keeper: 1.9 + 9.21 >= 99999999999999
# Cloud (1) > Roxas: 1.9 + 5.83 >= 99999999999999
# Cloud (1) > Saix: 1.9 + 10.3 >= 99999999999999
# Cloud (1) > Sark: 1.9 + 9.9 >= 99999999999999
# Cloud (1) > Scar: 1.9 + 6.34 >= 99999999999999
# Cloud (1) > Sephiroth: 1.9 + 6.57 >= 99999999999999
# Cloud (1) > Shan-Yu: 1.9 + 10.15 >= 99999999999999
# Cloud (1) > Storm Rider: 1.9 + 9.27 >= 99999999999999
# Cloud (1) > The Experiment: 1.9 + 11.7 >= 99999999999999
# Cloud (1) > Tifa: 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Tifa (1): 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Tifa (2): 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Twilight Thorn: 1.9 + 3.93 >= 99999999999999
# Cloud (1) > Vexen: 1.9 + 8.97 >= 99999999999999
# Cloud (1) > Volcano Lord: 1.9 + 10.32 >= 99999999999999
# Cloud (1) > Volcano Lord (Cups): 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Xaldin: 1.9 + 9.61 >= 99999999999999
# Cloud (1) > Xemnas: 1.9 + 6.16 >= 99999999999999
# Cloud (1) > Xigbar: 1.9 + 11.18 >= 99999999999999
# Cloud (1) > Yuffie: 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Yuffie (1): 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Yuffie (2): 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Yuffie (3): 1.9 + 9.14 >= 99999999999999
# Cloud (1) > Zexion: 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Armor Xemnas II: 1.9 + 9.23 >= 99999999999999
# Cloud (2) > Armor Xemnas I: 1.9 + 12.98 >= 99999999999999
# Cloud (2) > Axel I: 1.9 + 9.43 >= 99999999999999
# Cloud (2) > Axel II: 1.9 + 3.68 >= 99999999999999
# Cloud (2) > Blizzard Lord: 1.9 + 10.32 >= 99999999999999
# Cloud (2) > Blizzard Lord (Cups): 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Cerberus: 1.9 + 10.54 >= 99999999999999
# Cloud (2) > Cerberus (Cups): 1.9 + 0 >= 99999999999999
# Cloud (2) > Cloud: 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Cloud (1): 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Dark Thorn: 1.9 + 11.1 >= 99999999999999
# Cloud (2) > Demyx: 1.9 + 10.62 >= 99999999999999
# Cloud (2) > Grim Reaper I: 1.9 + 12.61 >= 99999999999999
# Cloud (2) > Groundshaker: 1.9 + 6.15 >= 99999999999999
# Cloud (2) > Hades Cups: 1.9 + 0 >= 99999999999999
# Cloud (2) > Hades II: 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Hades II (1): 1.9 + 0 >= 99999999999999
# Cloud (2) > Hercules: 1.9 + 0 >= 99999999999999
# Cloud (2) > Hostile Program: 1.9 + 9.16 >= 99999999999999
# Cloud (2) > Hydra: 1.9 + 10.22 >= 99999999999999
# Cloud (2) > Larxene: 1.9 + 8.3 >= 99999999999999
# Cloud (2) > Leon: 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Leon (1): 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Leon (2): 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Leon (3): 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Lexaeus: 1.9 + 8.36 >= 99999999999999
# Cloud (2) > Luxord: 1.9 + 7.25 >= 99999999999999
# Cloud (2) > Marluxia: 1.9 + 7.96 >= 99999999999999
# Cloud (2) > Past Pete: 1.9 + 11.16 >= 99999999999999
# Cloud (2) > Pete Cups: 1.9 + 0 >= 99999999999999
# Cloud (2) > Pete OC II: 1.9 + 13.53 >= 99999999999999
# Cloud (2) > Pete TR: 1.9 + 12.16 >= 99999999999999
# Cloud (2) > Prison Keeper: 1.9 + 9.21 >= 99999999999999
# Cloud (2) > Roxas: 1.9 + 5.83 >= 99999999999999
# Cloud (2) > Saix: 1.9 + 10.3 >= 99999999999999
# Cloud (2) > Sark: 1.9 + 9.9 >= 99999999999999
# Cloud (2) > Scar: 1.9 + 6.34 >= 99999999999999
# Cloud (2) > Sephiroth: 1.9 + 6.57 >= 99999999999999
# Cloud (2) > Shan-Yu: 1.9 + 10.15 >= 99999999999999
# Cloud (2) > Storm Rider: 1.9 + 9.27 >= 99999999999999
# Cloud (2) > The Experiment: 1.9 + 11.7 >= 99999999999999
# Cloud (2) > Tifa: 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Tifa (1): 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Tifa (2): 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Twilight Thorn: 1.9 + 3.93 >= 99999999999999
# Cloud (2) > Vexen: 1.9 + 8.97 >= 99999999999999
# Cloud (2) > Volcano Lord: 1.9 + 10.32 >= 99999999999999
# Cloud (2) > Volcano Lord (Cups): 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Xaldin: 1.9 + 9.61 >= 99999999999999
# Cloud (2) > Xemnas: 1.9 + 6.16 >= 99999999999999
# Cloud (2) > Xigbar: 1.9 + 11.18 >= 99999999999999
# Cloud (2) > Yuffie: 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Yuffie (1): 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Yuffie (2): 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Yuffie (3): 1.9 + 9.14 >= 99999999999999
# Cloud (2) > Zexion: 1.9 + 9.14 >= 99999999999999
# Dark Thorn > Armor Xemnas II: 4.19 + 9.23 >= 99999999999999
# Dark Thorn > Armor Xemnas I: 4.19 + 12.98 >= 99999999999999
# Dark Thorn > Axel I: 4.19 + 9.43 >= 99999999999999
# Dark Thorn > Axel II: 4.19 + 3.68 >= 99999999999999
# Dark Thorn > Blizzard Lord: 4.19 + 10.32 >= 99999999999999
# Dark Thorn > Blizzard Lord (Cups): 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Cerberus: 4.19 + 10.54 >= 99999999999999
# Dark Thorn > Cerberus (Cups): 4.19 + 0 >= 99999999999999
# Dark Thorn > Cloud: 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Cloud (1): 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Cloud (2): 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Demyx: 4.19 + 10.62 >= 99999999999999
# Dark Thorn > Grim Reaper I: 4.19 + 12.61 >= 99999999999999
# Dark Thorn > Groundshaker: 4.19 + 6.15 >= 99999999999999
# Dark Thorn > Hades Cups: 4.19 + 0 >= 99999999999999
# Dark Thorn > Hades II: 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Hades II (1): 4.19 + 0 >= 99999999999999
# Dark Thorn > Hercules: 4.19 + 0 >= 99999999999999
# Dark Thorn > Hostile Program: 4.19 + 9.16 >= 99999999999999
# Dark Thorn > Hydra: 4.19 + 10.22 >= 99999999999999
# Dark Thorn > Larxene: 4.19 + 8.3 >= 99999999999999
# Dark Thorn > Leon: 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Leon (1): 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Leon (2): 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Leon (3): 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Lexaeus: 4.19 + 8.36 >= 99999999999999
# Dark Thorn > Luxord: 4.19 + 7.25 >= 99999999999999
# Dark Thorn > Marluxia: 4.19 + 7.96 >= 99999999999999
# Dark Thorn > Past Pete: 4.19 + 11.16 >= 99999999999999
# Dark Thorn > Pete Cups: 4.19 + 0 >= 99999999999999
# Dark Thorn > Pete OC II: 4.19 + 13.53 >= 99999999999999
# Dark Thorn > Pete TR: 4.19 + 12.16 >= 99999999999999
# Dark Thorn > Prison Keeper: 4.19 + 9.21 >= 99999999999999
# Dark Thorn > Roxas: 4.19 + 5.83 >= 99999999999999
# Dark Thorn > Saix: 4.19 + 10.3 >= 99999999999999
# Dark Thorn > Sark: 4.19 + 9.9 >= 99999999999999
# Dark Thorn > Scar: 4.19 + 6.34 >= 99999999999999
# Dark Thorn > Sephiroth: 4.19 + 6.57 >= 99999999999999
# Dark Thorn > Shan-Yu: 4.19 + 10.15 >= 99999999999999
# Dark Thorn > Storm Rider: 4.19 + 9.27 >= 99999999999999
# Dark Thorn > The Experiment: 4.19 + 11.7 >= 99999999999999
# Dark Thorn > Tifa: 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Tifa (1): 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Tifa (2): 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Twilight Thorn: 4.19 + 3.93 >= 99999999999999
# Dark Thorn > Vexen: 4.19 + 8.97 >= 99999999999999
# Dark Thorn > Volcano Lord: 4.19 + 10.32 >= 99999999999999
# Dark Thorn > Volcano Lord (Cups): 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Xaldin: 4.19 + 9.61 >= 99999999999999
# Dark Thorn > Xemnas: 4.19 + 6.16 >= 99999999999999
# Dark Thorn > Xigbar: 4.19 + 11.18 >= 99999999999999
# Dark Thorn > Yuffie: 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Yuffie (1): 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Yuffie (2): 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Yuffie (3): 4.19 + 9.14 >= 99999999999999
# Dark Thorn > Zexion: 4.19 + 9.14 >= 99999999999999
# Demyx > Armor Xemnas II: 4.07 + 9.23 >= 99999999999999
# Demyx > Armor Xemnas I: 4.07 + 12.98 >= 99999999999999
# Demyx > Axel I: 4.07 + 9.43 >= 99999999999999
# Demyx > Axel II: 4.07 + 3.68 >= 99999999999999
# Demyx > Cerberus: 4.07 + 10.54 >= 99999999999999
# Demyx > Dark Thorn: 4.07 + 11.1 >= 99999999999999
# Demyx > Grim Reaper I: 4.07 + 12.61 >= 99999999999999
# Demyx > Groundshaker: 4.07 + 6.15 >= 99999999999999
# Demyx > Hades II: 4.07 + 9.14 >= 99999999999999
# Demyx > Hades II (1): 4.07 + 0 >= 99999999999999
# Demyx > Hostile Program: 4.07 + 9.16 >= 99999999999999
# Demyx > Hydra: 4.07 + 10.22 >= 99999999999999
# Demyx > Larxene: 4.07 + 8.3 >= 99999999999999
# Demyx > Lexaeus: 4.07 + 8.36 >= 99999999999999
# Demyx > Luxord: 4.07 + 7.25 >= 99999999999999
# Demyx > Marluxia: 4.07 + 7.96 >= 99999999999999
# Demyx > Past Pete: 4.07 + 11.16 >= 99999999999999
# Demyx > Pete TR: 4.07 + 12.16 >= 99999999999999
# Demyx > Prison Keeper: 4.07 + 9.21 >= 99999999999999
# Demyx > Roxas: 4.07 + 5.83 >= 99999999999999
# Demyx > Saix: 4.07 + 10.3 >= 99999999999999
# Demyx > Sark: 4.07 + 9.9 >= 99999999999999
# Demyx > Scar: 4.07 + 6.34 >= 99999999999999
# Demyx > Sephiroth: 4.07 + 6.57 >= 99999999999999
# Demyx > Shan-Yu: 4.07 + 10.15 >= 99999999999999
# Demyx > Storm Rider: 4.07 + 9.27 >= 99999999999999
# Demyx > The Experiment: 4.07 + 11.7 >= 99999999999999
# Demyx > Twilight Thorn: 4.07 + 3.93 >= 99999999999999
# Demyx > Vexen: 4.07 + 8.97 >= 99999999999999
# Demyx > Xaldin: 4.07 + 9.61 >= 99999999999999
# Demyx > Xemnas: 4.07 + 6.16 >= 99999999999999
# Demyx > Xigbar: 4.07 + 11.18 >= 99999999999999
# Demyx > Zexion: 4.07 + 9.14 >= 99999999999999
# Grim Reaper I > Armor Xemnas II: 2.35 + 9.23 >= 99999999999999
# Grim Reaper I > Armor Xemnas I: 2.35 + 12.98 >= 99999999999999
# Grim Reaper I > Axel I: 2.35 + 9.43 >= 99999999999999
# Grim Reaper I > Axel II: 2.35 + 3.68 >= 99999999999999
# Grim Reaper I > Blizzard Lord: 2.35 + 10.32 >= 99999999999999
# Grim Reaper I > Blizzard Lord (Cups): 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Cerberus: 2.35 + 10.54 >= 99999999999999
# Grim Reaper I > Cerberus (Cups): 2.35 + 0 >= 99999999999999
# Grim Reaper I > Cloud: 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Cloud (1): 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Cloud (2): 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Dark Thorn: 2.35 + 11.1 >= 99999999999999
# Grim Reaper I > Demyx: 2.35 + 10.62 >= 99999999999999
# Grim Reaper I > Groundshaker: 2.35 + 6.15 >= 99999999999999
# Grim Reaper I > Hades Cups: 2.35 + 0 >= 99999999999999
# Grim Reaper I > Hades II: 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Hades II (1): 2.35 + 0 >= 99999999999999
# Grim Reaper I > Hercules: 2.35 + 0 >= 99999999999999
# Grim Reaper I > Hostile Program: 2.35 + 9.16 >= 99999999999999
# Grim Reaper I > Hydra: 2.35 + 10.22 >= 99999999999999
# Grim Reaper I > Larxene: 2.35 + 8.3 >= 99999999999999
# Grim Reaper I > Leon: 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Leon (1): 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Leon (2): 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Leon (3): 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Lexaeus: 2.35 + 8.36 >= 99999999999999
# Grim Reaper I > Luxord: 2.35 + 7.25 >= 99999999999999
# Grim Reaper I > Marluxia: 2.35 + 7.96 >= 99999999999999
# Grim Reaper I > Past Pete: 2.35 + 11.16 >= 99999999999999
# Grim Reaper I > Pete Cups: 2.35 + 0 >= 99999999999999
# Grim Reaper I > Pete OC II: 2.35 + 13.53 >= 99999999999999
# Grim Reaper I > Pete TR: 2.35 + 12.16 >= 99999999999999
# Grim Reaper I > Prison Keeper: 2.35 + 9.21 >= 99999999999999
# Grim Reaper I > Roxas: 2.35 + 5.83 >= 99999999999999
# Grim Reaper I > Saix: 2.35 + 10.3 >= 99999999999999
# Grim Reaper I > Sark: 2.35 + 9.9 >= 99999999999999
# Grim Reaper I > Scar: 2.35 + 6.34 >= 99999999999999
# Grim Reaper I > Sephiroth: 2.35 + 6.57 >= 99999999999999
# Grim Reaper I > Shan-Yu: 2.35 + 10.15 >= 99999999999999
# Grim Reaper I > Storm Rider: 2.35 + 9.27 >= 99999999999999
# Grim Reaper I > The Experiment: 2.35 + 11.7 >= 99999999999999
# Grim Reaper I > Tifa: 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Tifa (1): 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Tifa (2): 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Twilight Thorn: 2.35 + 3.93 >= 99999999999999
# Grim Reaper I > Vexen: 2.35 + 8.97 >= 99999999999999
# Grim Reaper I > Volcano Lord: 2.35 + 10.32 >= 99999999999999
# Grim Reaper I > Volcano Lord (Cups): 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Xaldin: 2.35 + 9.61 >= 99999999999999
# Grim Reaper I > Xemnas: 2.35 + 6.16 >= 99999999999999
# Grim Reaper I > Xigbar: 2.35 + 11.18 >= 99999999999999
# Grim Reaper I > Yuffie: 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Yuffie (1): 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Yuffie (2): 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Yuffie (3): 2.35 + 9.14 >= 99999999999999
# Grim Reaper I > Zexion: 2.35 + 9.14 >= 99999999999999
# Groundshaker > Armor Xemnas II: 4.25 + 9.23 >= 99999999999999
# Groundshaker > Armor Xemnas I: 4.25 + 12.98 >= 99999999999999
# Groundshaker > Axel I: 4.25 + 9.43 >= 99999999999999
# Groundshaker > Axel II: 4.25 + 3.68 >= 99999999999999
# Groundshaker > Blizzard Lord: 4.25 + 10.32 >= 99999999999999
# Groundshaker > Blizzard Lord (Cups): 4.25 + 9.14 >= 99999999999999
# Groundshaker > Cerberus: 4.25 + 10.54 >= 99999999999999
# Groundshaker > Cerberus (Cups): 4.25 + 0 >= 99999999999999
# Groundshaker > Cloud: 4.25 + 9.14 >= 99999999999999
# Groundshaker > Cloud (1): 4.25 + 9.14 >= 99999999999999
# Groundshaker > Cloud (2): 4.25 + 9.14 >= 99999999999999
# Groundshaker > Dark Thorn: 4.25 + 11.1 >= 99999999999999
# Groundshaker > Demyx: 4.25 + 10.62 >= 99999999999999
# Groundshaker > Grim Reaper I: 4.25 + 12.61 >= 99999999999999
# Groundshaker > Hades Cups: 4.25 + 0 >= 99999999999999
# Groundshaker > Hades II: 4.25 + 9.14 >= 99999999999999
# Groundshaker > Hades II (1): 4.25 + 0 >= 99999999999999
# Groundshaker > Hercules: 4.25 + 0 >= 99999999999999
# Groundshaker > Hostile Program: 4.25 + 9.16 >= 99999999999999
# Groundshaker > Hydra: 4.25 + 10.22 >= 99999999999999
# Groundshaker > Larxene: 4.25 + 8.3 >= 99999999999999
# Groundshaker > Leon: 4.25 + 9.14 >= 99999999999999
# Groundshaker > Leon (1): 4.25 + 9.14 >= 99999999999999
# Groundshaker > Leon (2): 4.25 + 9.14 >= 99999999999999
# Groundshaker > Leon (3): 4.25 + 9.14 >= 99999999999999
# Groundshaker > Lexaeus: 4.25 + 8.36 >= 99999999999999
# Groundshaker > Luxord: 4.25 + 7.25 >= 99999999999999
# Groundshaker > Marluxia: 4.25 + 7.96 >= 99999999999999
# Groundshaker > Past Pete: 4.25 + 11.16 >= 99999999999999
# Groundshaker > Pete Cups: 4.25 + 0 >= 99999999999999
# Groundshaker > Pete OC II: 4.25 + 13.53 >= 99999999999999
# Groundshaker > Pete TR: 4.25 + 12.16 >= 99999999999999
# Groundshaker > Prison Keeper: 4.25 + 9.21 >= 99999999999999
# Groundshaker > Roxas: 4.25 + 5.83 >= 99999999999999
# Groundshaker > Saix: 4.25 + 10.3 >= 99999999999999
# Groundshaker > Sark: 4.25 + 9.9 >= 99999999999999
# Groundshaker > Scar: 4.25 + 6.34 >= 99999999999999
# Groundshaker > Sephiroth: 4.25 + 6.57 >= 99999999999999
# Groundshaker > Shan-Yu: 4.25 + 10.15 >= 99999999999999
# Groundshaker > Storm Rider: 4.25 + 9.27 >= 99999999999999
# Groundshaker > The Experiment: 4.25 + 11.7 >= 99999999999999
# Groundshaker > Tifa: 4.25 + 9.14 >= 99999999999999
# Groundshaker > Tifa (1): 4.25 + 9.14 >= 99999999999999
# Groundshaker > Tifa (2): 4.25 + 9.14 >= 99999999999999
# Groundshaker > Twilight Thorn: 4.25 + 3.93 >= 99999999999999
# Groundshaker > Vexen: 4.25 + 8.97 >= 99999999999999
# Groundshaker > Volcano Lord: 4.25 + 10.32 >= 99999999999999
# Groundshaker > Volcano Lord (Cups): 4.25 + 9.14 >= 99999999999999
# Groundshaker > Xaldin: 4.25 + 9.61 >= 99999999999999
# Groundshaker > Xemnas: 4.25 + 6.16 >= 99999999999999
# Groundshaker > Xigbar: 4.25 + 11.18 >= 99999999999999
# Groundshaker > Yuffie: 4.25 + 9.14 >= 99999999999999
# Groundshaker > Yuffie (1): 4.25 + 9.14 >= 99999999999999
# Groundshaker > Yuffie (2): 4.25 + 9.14 >= 99999999999999
# Groundshaker > Yuffie (3): 4.25 + 9.14 >= 99999999999999
# Groundshaker > Zexion: 4.25 + 9.14 >= 99999999999999
# Hades Cups > Armor Xemnas I: 3.14 + 12.98 >= 99999999999999
# Hades Cups > Blizzard Lord: 3.14 + 10.32 >= 99999999999999
# Hades Cups > Blizzard Lord (Cups): 3.14 + 9.14 >= 99999999999999
# Hades Cups > Cerberus: 3.14 + 10.54 >= 99999999999999
# Hades Cups > Cerberus (Cups): 3.14 + 0 >= 99999999999999
# Hades Cups > Cloud: 3.14 + 9.14 >= 99999999999999
# Hades Cups > Cloud (1): 3.14 + 9.14 >= 99999999999999
# Hades Cups > Cloud (2): 3.14 + 9.14 >= 99999999999999
# Hades Cups > Dark Thorn: 3.14 + 11.1 >= 99999999999999
# Hades Cups > Demyx: 3.14 + 10.62 >= 99999999999999
# Hades Cups > Grim Reaper I: 3.14 + 12.61 >= 99999999999999
# Hades Cups > Hades II: 3.14 + 9.14 >= 99999999999999
# Hades Cups > Hades II (1): 3.14 + 0 >= 99999999999999
# Hades Cups > Hercules: 3.14 + 0 >= 99999999999999
# Hades Cups > Hostile Program: 3.14 + 9.16 >= 99999999999999
# Hades Cups > Hydra: 3.14 + 10.22 >= 99999999999999
# Hades Cups > Larxene: 3.14 + 8.3 >= 99999999999999
# Hades Cups > Leon: 3.14 + 9.14 >= 99999999999999
# Hades Cups > Leon (1): 3.14 + 9.14 >= 99999999999999
# Hades Cups > Leon (2): 3.14 + 9.14 >= 99999999999999
# Hades Cups > Leon (3): 3.14 + 9.14 >= 99999999999999
# Hades Cups > Lexaeus: 3.14 + 8.36 >= 99999999999999
# Hades Cups > Luxord: 3.14 + 7.25 >= 99999999999999
# Hades Cups > Marluxia: 3.14 + 7.96 >= 99999999999999
# Hades Cups > Pete Cups: 3.14 + 0 >= 99999999999999
# Hades Cups > Pete OC II: 3.14 + 13.53 >= 99999999999999
# Hades Cups > Pete TR: 3.14 + 12.16 >= 99999999999999
# Hades Cups > Roxas: 3.14 + 5.83 >= 99999999999999
# Hades Cups > Saix: 3.14 + 10.3 >= 99999999999999
# Hades Cups > Sark: 3.14 + 9.9 >= 99999999999999
# Hades Cups > Scar: 3.14 + 6.34 >= 99999999999999
# Hades Cups > Sephiroth: 3.14 + 6.57 >= 99999999999999
# Hades Cups > Shan-Yu: 3.14 + 10.15 >= 99999999999999
# Hades Cups > Storm Rider: 3.14 + 9.27 >= 99999999999999
# Hades Cups > The Experiment: 3.14 + 11.7 >= 99999999999999
# Hades Cups > Tifa: 3.14 + 9.14 >= 99999999999999
# Hades Cups > Tifa (1): 3.14 + 9.14 >= 99999999999999
# Hades Cups > Tifa (2): 3.14 + 9.14 >= 99999999999999
# Hades Cups > Vexen: 3.14 + 8.97 >= 99999999999999
# Hades Cups > Volcano Lord: 3.14 + 10.32 >= 99999999999999
# Hades Cups > Volcano Lord (Cups): 3.14 + 9.14 >= 99999999999999
# Hades Cups > Xaldin: 3.14 + 9.61 >= 99999999999999
# Hades Cups > Xemnas: 3.14 + 6.16 >= 99999999999999
# Hades Cups > Xigbar: 3.14 + 11.18 >= 99999999999999
# Hades Cups > Yuffie: 3.14 + 9.14 >= 99999999999999
# Hades Cups > Yuffie (1): 3.14 + 9.14 >= 99999999999999
# Hades Cups > Yuffie (2): 3.14 + 9.14 >= 99999999999999
# Hades Cups > Yuffie (3): 3.14 + 9.14 >= 99999999999999
# Hades Cups > Zexion: 3.14 + 9.14 >= 99999999999999
# Hades II > Armor Xemnas II: 3.15 + 9.23 >= 99999999999999
# Hades II > Armor Xemnas I: 3.15 + 12.98 >= 99999999999999
# Hades II > Axel I: 3.15 + 9.43 >= 99999999999999
# Hades II > Axel II: 3.15 + 3.68 >= 99999999999999
# Hades II > Blizzard Lord: 3.15 + 10.32 >= 99999999999999
# Hades II > Blizzard Lord (Cups): 3.15 + 9.14 >= 99999999999999
# Hades II > Cerberus: 3.15 + 10.54 >= 99999999999999
# Hades II > Cerberus (Cups): 3.15 + 0 >= 99999999999999
# Hades II > Cloud: 3.15 + 9.14 >= 99999999999999
# Hades II > Cloud (1): 3.15 + 9.14 >= 99999999999999
# Hades II > Cloud (2): 3.15 + 9.14 >= 99999999999999
# Hades II > Dark Thorn: 3.15 + 11.1 >= 99999999999999
# Hades II > Demyx: 3.15 + 10.62 >= 99999999999999
# Hades II > Grim Reaper I: 3.15 + 12.61 >= 99999999999999
# Hades II > Groundshaker: 3.15 + 6.15 >= 99999999999999
# Hades II > Hades Cups: 3.15 + 0 >= 99999999999999
# Hades II > Hades II (1): 3.15 + 0 >= 99999999999999
# Hades II > Hercules: 3.15 + 0 >= 99999999999999
# Hades II > Hostile Program: 3.15 + 9.16 >= 99999999999999
# Hades II > Hydra: 3.15 + 10.22 >= 99999999999999
# Hades II > Larxene: 3.15 + 8.3 >= 99999999999999
# Hades II > Leon: 3.15 + 9.14 >= 99999999999999
# Hades II > Leon (1): 3.15 + 9.14 >= 99999999999999
# Hades II > Leon (2): 3.15 + 9.14 >= 99999999999999
# Hades II > Leon (3): 3.15 + 9.14 >= 99999999999999
# ...
# Xaldin > Hydra: 3.63 + 10.22 >= 16.8
# Xaldin > Larxene: 3.63 + 8.3 >= 16.8
# Xaldin > Leon: 3.63 + 9.14 >= 16.8
# Xaldin > Leon (1): 3.63 + 9.14 >= 16.8
# Xaldin > Leon (2): 3.63 + 9.14 >= 16.8
# Xaldin > Leon (3): 3.63 + 9.14 >= 16.8
# Xaldin > Lexaeus: 3.63 + 8.36 >= 16.8
# Xaldin > Luxord: 3.63 + 7.25 >= 16.8
# Xaldin > Marluxia: 3.63 + 7.96 >= 16.8
# Xaldin > Past Pete: 3.63 + 11.16 >= 16.8
# Xaldin > Pete Cups: 3.63 + 0 >= 16.8
# Xaldin > Pete OC II: 3.63 + 13.53 >= 16.8
# Xaldin > Pete TR: 3.63 + 12.16 >= 16.8
# Xaldin > Prison Keeper: 3.63 + 9.21 >= 16.8
# Xaldin > Roxas: 3.63 + 5.83 >= 16.8
# Xaldin > Saix: 3.63 + 10.3 >= 16.8
# Xaldin > Sark: 3.63 + 9.9 >= 16.8
# Xaldin > Scar: 3.63 + 6.34 >= 16.8
# Xaldin > Sephiroth: 3.63 + 6.57 >= 16.8
# Xaldin > Shan-Yu: 3.63 + 10.15 >= 16.8
# Xaldin > Storm Rider: 3.63 + 9.27 >= 16.8
# Xaldin > The Experiment: 3.63 + 11.7 >= 16.8
# Xaldin > Tifa: 3.63 + 9.14 >= 16.8
# Xaldin > Tifa (1): 3.63 + 9.14 >= 16.8
# Xaldin > Tifa (2): 3.63 + 9.14 >= 16.8
# Xaldin > Twilight Thorn: 3.63 + 3.93 >= 16.8
# Xaldin > Vexen: 3.63 + 8.97 >= 16.8
# Xaldin > Volcano Lord: 3.63 + 10.32 >= 16.8
# Xaldin > Volcano Lord (Cups): 3.63 + 9.14 >= 16.8
# Xaldin > Xemnas: 3.63 + 6.16 >= 16.8
# Xaldin > Xigbar: 3.63 + 11.18 >= 16.8
# Xaldin > Yuffie: 3.63 + 9.14 >= 16.8
# Xaldin > Yuffie (1): 3.63 + 9.14 >= 16.8
# Xaldin > Yuffie (2): 3.63 + 9.14 >= 16.8
# Xaldin > Yuffie (3): 3.63 + 9.14 >= 16.8
# Xaldin > Zexion: 3.63 + 9.14 >= 16.8
# Xemnas > Armor Xemnas II: 3.7 + 9.23 >= 16.8
# Xemnas > Armor Xemnas I: 3.7 + 12.98 >= 16.8
# Xemnas > Axel I: 3.7 + 9.43 >= 16.8
# Xemnas > Axel II: 3.7 + 3.68 >= 16.8
# Xemnas > Blizzard Lord: 3.7 + 10.32 >= 16.8
# Xemnas > Blizzard Lord (Cups): 3.7 + 9.14 >= 16.8
# Xemnas > Cerberus: 3.7 + 10.54 >= 16.8
# Xemnas > Cerberus (Cups): 3.7 + 0 >= 16.8
# Xemnas > Cloud: 3.7 + 9.14 >= 16.8
# Xemnas > Cloud (1): 3.7 + 9.14 >= 16.8
# Xemnas > Cloud (2): 3.7 + 9.14 >= 16.8
# Xemnas > Dark Thorn: 3.7 + 11.1 >= 16.8
# Xemnas > Demyx: 3.7 + 10.62 >= 16.8
# Xemnas > Grim Reaper I: 3.7 + 12.61 >= 16.8
# Xemnas > Groundshaker: 3.7 + 6.15 >= 16.8
# Xemnas > Hades Cups: 3.7 + 0 >= 16.8
# Xemnas > Hades II: 3.7 + 9.14 >= 16.8
# Xemnas > Hades II (1): 3.7 + 0 >= 16.8
# Xemnas > Hercules: 3.7 + 0 >= 16.8
# Xemnas > Hostile Program: 3.7 + 9.16 >= 16.8
# Xemnas > Hydra: 3.7 + 10.22 >= 16.8
# Xemnas > Larxene: 3.7 + 8.3 >= 16.8
# Xemnas > Leon: 3.7 + 9.14 >= 16.8
# Xemnas > Leon (1): 3.7 + 9.14 >= 16.8
# Xemnas > Leon (2): 3.7 + 9.14 >= 16.8
# Xemnas > Leon (3): 3.7 + 9.14 >= 16.8
# Xemnas > Lexaeus: 3.7 + 8.36 >= 16.8
# Xemnas > Luxord: 3.7 + 7.25 >= 16.8
# Xemnas > Marluxia: 3.7 + 7.96 >= 16.8
# Xemnas > Past Pete: 3.7 + 11.16 >= 16.8
# Xemnas > Pete Cups: 3.7 + 0 >= 16.8
# Xemnas > Pete OC II: 3.7 + 13.53 >= 16.8
# Xemnas > Pete TR: 3.7 + 12.16 >= 16.8
# Xemnas > Prison Keeper: 3.7 + 9.21 >= 16.8
# Xemnas > Roxas: 3.7 + 5.83 >= 16.8
# Xemnas > Saix: 3.7 + 10.3 >= 16.8
# Xemnas > Sark: 3.7 + 9.9 >= 16.8
# Xemnas > Scar: 3.7 + 6.34 >= 16.8
# Xemnas > Sephiroth: 3.7 + 6.57 >= 16.8
# Xemnas > Shan-Yu: 3.7 + 10.15 >= 16.8
# Xemnas > Storm Rider: 3.7 + 9.27 >= 16.8
# Xemnas > The Experiment: 3.7 + 11.7 >= 16.8
# Xemnas > Tifa: 3.7 + 9.14 >= 16.8
# Xemnas > Tifa (1): 3.7 + 9.14 >= 16.8
# Xemnas > Tifa (2): 3.7 + 9.14 >= 16.8
# Xemnas > Twilight Thorn: 3.7 + 3.93 >= 16.8
# Xemnas > Vexen: 3.7 + 8.97 >= 16.8
# Xemnas > Volcano Lord: 3.7 + 10.32 >= 16.8
# Xemnas > Volcano Lord (Cups): 3.7 + 9.14 >= 16.8
# Xemnas > Xaldin: 3.7 + 9.61 >= 16.8
# Xemnas > Xigbar: 3.7 + 11.18 >= 16.8
# Xemnas > Yuffie: 3.7 + 9.14 >= 16.8
# Xemnas > Yuffie (1): 3.7 + 9.14 >= 16.8
# Xemnas > Yuffie (2): 3.7 + 9.14 >= 16.8
# Xemnas > Yuffie (3): 3.7 + 9.14 >= 16.8
# Xemnas > Zexion: 3.7 + 9.14 >= 16.8
# Xigbar > Blizzard Lord: 3.19 + 10.32 >= 16.8
# Xigbar > Blizzard Lord (Cups): 3.19 + 9.14 >= 16.8
# Xigbar > Cerberus: 3.19 + 10.54 >= 16.8
# Xigbar > Cerberus (Cups): 3.19 + 0 >= 16.8
# Xigbar > Cloud: 3.19 + 9.14 >= 16.8
# Xigbar > Cloud (1): 3.19 + 9.14 >= 16.8
# Xigbar > Cloud (2): 3.19 + 9.14 >= 16.8
# Xigbar > Dark Thorn: 3.19 + 11.1 >= 16.8
# Xigbar > Demyx: 3.19 + 10.62 >= 16.8
# Xigbar > Grim Reaper I: 3.19 + 12.61 >= 16.8
# Xigbar > Hades Cups: 3.19 + 0 >= 16.8
# Xigbar > Hades II: 3.19 + 9.14 >= 16.8
# Xigbar > Hades II (1): 3.19 + 0 >= 16.8
# Xigbar > Hercules: 3.19 + 0 >= 16.8
# Xigbar > Hostile Program: 3.19 + 9.16 >= 16.8
# Xigbar > Hydra: 3.19 + 10.22 >= 16.8
# Xigbar > Larxene: 3.19 + 8.3 >= 16.8
# Xigbar > Leon: 3.19 + 9.14 >= 16.8
# Xigbar > Leon (1): 3.19 + 9.14 >= 16.8
# Xigbar > Leon (2): 3.19 + 9.14 >= 16.8
# Xigbar > Leon (3): 3.19 + 9.14 >= 16.8
# Xigbar > Lexaeus: 3.19 + 8.36 >= 16.8
# Xigbar > Luxord: 3.19 + 7.25 >= 16.8
# Xigbar > Marluxia: 3.19 + 7.96 >= 16.8
# Xigbar > Pete Cups: 3.19 + 0 >= 16.8
# Xigbar > Pete TR: 3.19 + 12.16 >= 16.8
# Xigbar > Saix: 3.19 + 10.3 >= 16.8
# Xigbar > Sephiroth: 3.19 + 6.57 >= 16.8
# Xigbar > Shan-Yu: 3.19 + 10.15 >= 16.8
# Xigbar > Storm Rider: 3.19 + 9.27 >= 16.8
# Xigbar > The Experiment: 3.19 + 11.7 >= 16.8
# Xigbar > Tifa: 3.19 + 9.14 >= 16.8
# Xigbar > Tifa (1): 3.19 + 9.14 >= 16.8
# Xigbar > Tifa (2): 3.19 + 9.14 >= 16.8
# Xigbar > Vexen: 3.19 + 8.97 >= 16.8
# Xigbar > Volcano Lord: 3.19 + 10.32 >= 16.8
# Xigbar > Volcano Lord (Cups): 3.19 + 9.14 >= 16.8
# Xigbar > Xaldin: 3.19 + 9.61 >= 16.8
# Xigbar > Xemnas: 3.19 + 6.16 >= 16.8
# Xigbar > Yuffie: 3.19 + 9.14 >= 16.8
# Xigbar > Yuffie (1): 3.19 + 9.14 >= 16.8
# Xigbar > Yuffie (2): 3.19 + 9.14 >= 16.8
# Xigbar > Yuffie (3): 3.19 + 9.14 >= 16.8
# Xigbar > Zexion: 3.19 + 9.14 >= 16.8
# Yuffie > Armor Xemnas II: 0.95 + 9.23 >= 16.8
# Yuffie > Armor Xemnas I: 0.95 + 12.98 >= 16.8
# Yuffie > Axel I: 0.95 + 9.43 >= 16.8
# Yuffie > Axel II: 0.95 + 3.68 >= 16.8
# Yuffie > Blizzard Lord: 0.95 + 10.32 >= 16.8
# Yuffie > Blizzard Lord (Cups): 0.95 + 9.14 >= 16.8
# Yuffie > Cerberus: 0.95 + 10.54 >= 16.8
# Yuffie > Cerberus (Cups): 0.95 + 0 >= 16.8
# Yuffie > Cloud: 0.95 + 9.14 >= 16.8
# Yuffie > Cloud (1): 0.95 + 9.14 >= 16.8
# Yuffie > Cloud (2): 0.95 + 9.14 >= 16.8
# Yuffie > Dark Thorn: 0.95 + 11.1 >= 16.8
# Yuffie > Demyx: 0.95 + 10.62 >= 16.8
# Yuffie > Grim Reaper I: 0.95 + 12.61 >= 16.8
# Yuffie > Groundshaker: 0.95 + 6.15 >= 16.8
# Yuffie > Hades Cups: 0.95 + 0 >= 16.8
# Yuffie > Hades II: 0.95 + 9.14 >= 16.8
# Yuffie > Hades II (1): 0.95 + 0 >= 16.8
# Yuffie > Hercules: 0.95 + 0 >= 16.8
# Yuffie > Hostile Program: 0.95 + 9.16 >= 16.8
# Yuffie > Hydra: 0.95 + 10.22 >= 16.8
# Yuffie > Larxene: 0.95 + 8.3 >= 16.8
# Yuffie > Leon: 0.95 + 9.14 >= 16.8
# Yuffie > Leon (1): 0.95 + 9.14 >= 16.8
# Yuffie > Leon (2): 0.95 + 9.14 >= 16.8
# Yuffie > Leon (3): 0.95 + 9.14 >= 16.8
# Yuffie > Lexaeus: 0.95 + 8.36 >= 16.8
# Yuffie > Luxord: 0.95 + 7.25 >= 16.8
# Yuffie > Marluxia: 0.95 + 7.96 >= 16.8
# Yuffie > Past Pete: 0.95 + 11.16 >= 16.8
# Yuffie > Pete Cups: 0.95 + 0 >= 16.8
# Yuffie > Pete OC II: 0.95 + 13.53 >= 16.8
# Yuffie > Pete TR: 0.95 + 12.16 >= 16.8
# Yuffie > Prison Keeper: 0.95 + 9.21 >= 16.8
# Yuffie > Roxas: 0.95 + 5.83 >= 16.8
# Yuffie > Saix: 0.95 + 10.3 >= 16.8
# Yuffie > Sark: 0.95 + 9.9 >= 16.8
# Yuffie > Scar: 0.95 + 6.34 >= 16.8
# Yuffie > Sephiroth: 0.95 + 6.57 >= 16.8
# Yuffie > Shan-Yu: 0.95 + 10.15 >= 16.8
# Yuffie > Storm Rider: 0.95 + 9.27 >= 16.8
# Yuffie > The Experiment: 0.95 + 11.7 >= 16.8
# Yuffie > Tifa: 0.95 + 9.14 >= 16.8
# Yuffie > Tifa (1): 0.95 + 9.14 >= 16.8
# Yuffie > Tifa (2): 0.95 + 9.14 >= 16.8
# Yuffie > Twilight Thorn: 0.95 + 3.93 >= 16.8
# Yuffie > Vexen: 0.95 + 8.97 >= 16.8
# Yuffie > Volcano Lord: 0.95 + 10.32 >= 16.8
# Yuffie > Volcano Lord (Cups): 0.95 + 9.14 >= 16.8
# Yuffie > Xaldin: 0.95 + 9.61 >= 16.8
# Yuffie > Xemnas: 0.95 + 6.16 >= 16.8
# Yuffie > Xigbar: 0.95 + 11.18 >= 16.8
# Yuffie > Yuffie (1): 0.95 + 9.14 >= 16.8
# Yuffie > Yuffie (2): 0.95 + 9.14 >= 16.8
# Yuffie > Yuffie (3): 0.95 + 9.14 >= 16.8
# Yuffie > Zexion: 0.95 + 9.14 >= 16.8
# Yuffie (1) > Armor Xemnas II: 0.95 + 9.23 >= 16.8
# Yuffie (1) > Armor Xemnas I: 0.95 + 12.98 >= 16.8
# Yuffie (1) > Axel I: 0.95 + 9.43 >= 16.8
# Yuffie (1) > Axel II: 0.95 + 3.68 >= 16.8
# Yuffie (1) > Blizzard Lord: 0.95 + 10.32 >= 16.8
# Yuffie (1) > Blizzard Lord (Cups): 0.95 + 9.14 >= 16.8
# Yuffie (1) > Cerberus: 0.95 + 10.54 >= 16.8
# Yuffie (1) > Cerberus (Cups): 0.95 + 0 >= 16.8
# Yuffie (1) > Cloud: 0.95 + 9.14 >= 16.8
# Yuffie (1) > Cloud (1): 0.95 + 9.14 >= 16.8
# Yuffie (1) > Cloud (2): 0.95 + 9.14 >= 16.8
# Yuffie (1) > Dark Thorn: 0.95 + 11.1 >= 16.8
# Yuffie (1) > Demyx: 0.95 + 10.62 >= 16.8
# Yuffie (1) > Grim Reaper I: 0.95 + 12.61 >= 16.8
# Yuffie (1) > Groundshaker: 0.95 + 6.15 >= 16.8
# Yuffie (1) > Hades Cups: 0.95 + 0 >= 16.8
# Yuffie (1) > Hades II: 0.95 + 9.14 >= 16.8
# Yuffie (1) > Hades II (1): 0.95 + 0 >= 16.8
# Yuffie (1) > Hercules: 0.95 + 0 >= 16.8
# Yuffie (1) > Hostile Program: 0.95 + 9.16 >= 16.8
# Yuffie (1) > Hydra: 0.95 + 10.22 >= 16.8
# Yuffie (1) > Larxene: 0.95 + 8.3 >= 16.8
# Yuffie (1) > Leon: 0.95 + 9.14 >= 16.8
# Yuffie (1) > Leon (1): 0.95 + 9.14 >= 16.8
# Yuffie (1) > Leon (2): 0.95 + 9.14 >= 16.8
# Yuffie (1) > Leon (3): 0.95 + 9.14 >= 16.8
# Yuffie (1) > Lexaeus: 0.95 + 8.36 >= 16.8
# Yuffie (1) > Luxord: 0.95 + 7.25 >= 16.8
# Yuffie (1) > Marluxia: 0.95 + 7.96 >= 16.8
# Yuffie (1) > Past Pete: 0.95 + 11.16 >= 16.8
# Yuffie (1) > Pete Cups: 0.95 + 0 >= 16.8
# Yuffie (1) > Pete OC II: 0.95 + 13.53 >= 16.8
# Yuffie (1) > Pete TR: 0.95 + 12.16 >= 16.8
# Yuffie (1) > Prison Keeper: 0.95 + 9.21 >= 16.8
# Yuffie (1) > Roxas: 0.95 + 5.83 >= 16.8
# Yuffie (1) > Saix: 0.95 + 10.3 >= 16.8
# Yuffie (1) > Sark: 0.95 + 9.9 >= 16.8
# Yuffie (1) > Scar: 0.95 + 6.34 >= 16.8
# Yuffie (1) > Sephiroth: 0.95 + 6.57 >= 16.8
# Yuffie (1) > Shan-Yu: 0.95 + 10.15 >= 16.8
# Yuffie (1) > Storm Rider: 0.95 + 9.27 >= 16.8
# Yuffie (1) > The Experiment: 0.95 + 11.7 >= 16.8
# Yuffie (1) > Tifa: 0.95 + 9.14 >= 16.8
# Yuffie (1) > Tifa (1): 0.95 + 9.14 >= 16.8
# Yuffie (1) > Tifa (2): 0.95 + 9.14 >= 16.8
# Yuffie (1) > Twilight Thorn: 0.95 + 3.93 >= 16.8
# Yuffie (1) > Vexen: 0.95 + 8.97 >= 16.8
# Yuffie (1) > Volcano Lord: 0.95 + 10.32 >= 16.8
# Yuffie (1) > Volcano Lord (Cups): 0.95 + 9.14 >= 16.8
# Yuffie (1) > Xaldin: 0.95 + 9.61 >= 16.8
# Yuffie (1) > Xemnas: 0.95 + 6.16 >= 16.8
# Yuffie (1) > Xigbar: 0.95 + 11.18 >= 16.8
# Yuffie (1) > Yuffie: 0.95 + 9.14 >= 16.8
# Yuffie (1) > Yuffie (2): 0.95 + 9.14 >= 16.8
# Yuffie (1) > Yuffie (3): 0.95 + 9.14 >= 16.8
# Yuffie (1) > Zexion: 0.95 + 9.14 >= 16.8
# Yuffie (2) > Armor Xemnas II: 0.95 + 9.23 >= 16.8
# Yuffie (2) > Armor Xemnas I: 0.95 + 12.98 >= 16.8
# Yuffie (2) > Axel I: 0.95 + 9.43 >= 16.8
# Yuffie (2) > Axel II: 0.95 + 3.68 >= 16.8
# Yuffie (2) > Blizzard Lord: 0.95 + 10.32 >= 16.8
# Yuffie (2) > Blizzard Lord (Cups): 0.95 + 9.14 >= 16.8
# Yuffie (2) > Cerberus: 0.95 + 10.54 >= 16.8
# Yuffie (2) > Cerberus (Cups): 0.95 + 0 >= 16.8
# Yuffie (2) > Cloud: 0.95 + 9.14 >= 16.8
# Yuffie (2) > Cloud (1): 0.95 + 9.14 >= 16.8
# Yuffie (2) > Cloud (2): 0.95 + 9.14 >= 16.8
# Yuffie (2) > Dark Thorn: 0.95 + 11.1 >= 16.8
# Yuffie (2) > Demyx: 0.95 + 10.62 >= 16.8
# Yuffie (2) > Grim Reaper I: 0.95 + 12.61 >= 16.8
# Yuffie (2) > Groundshaker: 0.95 + 6.15 >= 16.8
# Yuffie (2) > Hades Cups: 0.95 + 0 >= 16.8
# Yuffie (2) > Hades II: 0.95 + 9.14 >= 16.8
# Yuffie (2) > Hades II (1): 0.95 + 0 >= 16.8
# Yuffie (2) > Hercules: 0.95 + 0 >= 16.8
# Yuffie (2) > Hostile Program: 0.95 + 9.16 >= 16.8
# Yuffie (2) > Hydra: 0.95 + 10.22 >= 16.8
# Yuffie (2) > Larxene: 0.95 + 8.3 >= 16.8
# Yuffie (2) > Leon: 0.95 + 9.14 >= 16.8
# Yuffie (2) > Leon (1): 0.95 + 9.14 >= 16.8
# Yuffie (2) > Leon (2): 0.95 + 9.14 >= 16.8
# Yuffie (2) > Leon (3): 0.95 + 9.14 >= 16.8
# Yuffie (2) > Lexaeus: 0.95 + 8.36 >= 16.8
# Yuffie (2) > Luxord: 0.95 + 7.25 >= 16.8
# Yuffie (2) > Marluxia: 0.95 + 7.96 >= 16.8
# Yuffie (2) > Past Pete: 0.95 + 11.16 >= 16.8
# Yuffie (2) > Pete Cups: 0.95 + 0 >= 16.8
# Yuffie (2) > Pete OC II: 0.95 + 13.53 >= 16.8
# Yuffie (2) > Pete TR: 0.95 + 12.16 >= 16.8
# Yuffie (2) > Prison Keeper: 0.95 + 9.21 >= 16.8
# Yuffie (2) > Roxas: 0.95 + 5.83 >= 16.8
# Yuffie (2) > Saix: 0.95 + 10.3 >= 16.8
# Yuffie (2) > Sark: 0.95 + 9.9 >= 16.8
# Yuffie (2) > Scar: 0.95 + 6.34 >= 16.8
# Yuffie (2) > Sephiroth: 0.95 + 6.57 >= 16.8
# Yuffie (2) > Shan-Yu: 0.95 + 10.15 >= 16.8
# Yuffie (2) > Storm Rider: 0.95 + 9.27 >= 16.8
# Yuffie (2) > The Experiment: 0.95 + 11.7 >= 16.8
# Yuffie (2) > Tifa: 0.95 + 9.14 >= 16.8
# Yuffie (2) > Tifa (1): 0.95 + 9.14 >= 16.8
# Yuffie (2) > Tifa (2): 0.95 + 9.14 >= 16.8
# Yuffie (2) > Twilight Thorn: 0.95 + 3.93 >= 16.8
# Yuffie (2) > Vexen: 0.95 + 8.97 >= 16.8
# Yuffie (2) > Volcano Lord: 0.95 + 10.32 >= 16.8
# Yuffie (2) > Volcano Lord (Cups): 0.95 + 9.14 >= 16.8
# Yuffie (2) > Xaldin: 0.95 + 9.61 >= 16.8
# Yuffie (2) > Xemnas: 0.95 + 6.16 >= 16.8
# Yuffie (2) > Xigbar: 0.95 + 11.18 >= 16.8
# Yuffie (2) > Yuffie: 0.95 + 9.14 >= 16.8
# Yuffie (2) > Yuffie (1): 0.95 + 9.14 >= 16.8
# Yuffie (2) > Yuffie (3): 0.95 + 9.14 >= 16.8
# Yuffie (2) > Zexion: 0.95 + 9.14 >= 16.8
# Yuffie (3) > Armor Xemnas II: 0.95 + 9.23 >= 16.8
# Yuffie (3) > Armor Xemnas I: 0.95 + 12.98 >= 16.8
# Yuffie (3) > Axel I: 0.95 + 9.43 >= 16.8
# Yuffie (3) > Axel II: 0.95 + 3.68 >= 16.8
# Yuffie (3) > Blizzard Lord: 0.95 + 10.32 >= 16.8
# Yuffie (3) > Blizzard Lord (Cups): 0.95 + 9.14 >= 16.8
# Yuffie (3) > Cerberus: 0.95 + 10.54 >= 16.8
# Yuffie (3) > Cerberus (Cups): 0.95 + 0 >= 16.8
# Yuffie (3) > Cloud: 0.95 + 9.14 >= 16.8
# Yuffie (3) > Cloud (1): 0.95 + 9.14 >= 16.8
# Yuffie (3) > Cloud (2): 0.95 + 9.14 >= 16.8
# Yuffie (3) > Dark Thorn: 0.95 + 11.1 >= 16.8
# Yuffie (3) > Demyx: 0.95 + 10.62 >= 16.8
# Yuffie (3) > Grim Reaper I: 0.95 + 12.61 >= 16.8
# Yuffie (3) > Groundshaker: 0.95 + 6.15 >= 16.8
# Yuffie (3) > Hades Cups: 0.95 + 0 >= 16.8
# Yuffie (3) > Hades II: 0.95 + 9.14 >= 16.8
# Yuffie (3) > Hades II (1): 0.95 + 0 >= 16.8
# Yuffie (3) > Hercules: 0.95 + 0 >= 16.8
# Yuffie (3) > Hostile Program: 0.95 + 9.16 >= 16.8
# Yuffie (3) > Hydra: 0.95 + 10.22 >= 16.8
# Yuffie (3) > Larxene: 0.95 + 8.3 >= 16.8
# Yuffie (3) > Leon: 0.95 + 9.14 >= 16.8
# Yuffie (3) > Leon (1): 0.95 + 9.14 >= 16.8
# Yuffie (3) > Leon (2): 0.95 + 9.14 >= 16.8
# Yuffie (3) > Leon (3): 0.95 + 9.14 >= 16.8
# Yuffie (3) > Lexaeus: 0.95 + 8.36 >= 16.8
# Yuffie (3) > Luxord: 0.95 + 7.25 >= 16.8
# Yuffie (3) > Marluxia: 0.95 + 7.96 >= 16.8
# Yuffie (3) > Past Pete: 0.95 + 11.16 >= 16.8
# Yuffie (3) > Pete Cups: 0.95 + 0 >= 16.8
# Yuffie (3) > Pete OC II: 0.95 + 13.53 >= 16.8
# Yuffie (3) > Pete TR: 0.95 + 12.16 >= 16.8
# Yuffie (3) > Prison Keeper: 0.95 + 9.21 >= 16.8
# Yuffie (3) > Roxas: 0.95 + 5.83 >= 16.8
# Yuffie (3) > Saix: 0.95 + 10.3 >= 16.8
# Yuffie (3) > Sark: 0.95 + 9.9 >= 16.8
# Yuffie (3) > Scar: 0.95 + 6.34 >= 16.8
# Yuffie (3) > Sephiroth: 0.95 + 6.57 >= 16.8
# Yuffie (3) > Shan-Yu: 0.95 + 10.15 >= 16.8
# Yuffie (3) > Storm Rider: 0.95 + 9.27 >= 16.8
# Yuffie (3) > The Experiment: 0.95 + 11.7 >= 16.8
# Yuffie (3) > Tifa: 0.95 + 9.14 >= 16.8
# Yuffie (3) > Tifa (1): 0.95 + 9.14 >= 16.8
# Yuffie (3) > Tifa (2): 0.95 + 9.14 >= 16.8
# Yuffie (3) > Twilight Thorn: 0.95 + 3.93 >= 16.8
# Yuffie (3) > Vexen: 0.95 + 8.97 >= 16.8
# Yuffie (3) > Volcano Lord: 0.95 + 10.32 >= 16.8
# Yuffie (3) > Volcano Lord (Cups): 0.95 + 9.14 >= 16.8
# Yuffie (3) > Xaldin: 0.95 + 9.61 >= 16.8
# Yuffie (3) > Xemnas: 0.95 + 6.16 >= 16.8
# Yuffie (3) > Xigbar: 0.95 + 11.18 >= 16.8
# Yuffie (3) > Yuffie: 0.95 + 9.14 >= 16.8
# Yuffie (3) > Yuffie (1): 0.95 + 9.14 >= 16.8
# Yuffie (3) > Yuffie (2): 0.95 + 9.14 >= 16.8
# Yuffie (3) > Zexion: 0.95 + 9.14 >= 16.8
# Zexion > Armor Xemnas I: 4.44 + 12.98 >= 16.8
# Zexion > Cerberus: 4.44 + 10.54 >= 16.8
# Zexion > Dark Thorn: 4.44 + 11.1 >= 16.8
# Zexion > Demyx: 4.44 + 10.62 >= 16.8
# Zexion > Grim Reaper I: 4.44 + 12.61 >= 16.8
# Zexion > Hades II: 4.44 + 9.14 >= 16.8
# Zexion > Hades II (1): 4.44 + 0 >= 16.8
# Zexion > Hostile Program: 4.44 + 9.16 >= 16.8
# Zexion > Hydra: 4.44 + 10.22 >= 16.8
# Zexion > Larxene: 4.44 + 8.3 >= 16.8
# Zexion > Lexaeus: 4.44 + 8.36 >= 16.8
# Zexion > Luxord: 4.44 + 7.25 >= 16.8
# Zexion > Marluxia: 4.44 + 7.96 >= 16.8
# Zexion > Pete TR: 4.44 + 12.16 >= 16.8
# Zexion > Roxas: 4.44 + 5.83 >= 16.8
# Zexion > Saix: 4.44 + 10.3 >= 16.8
# Zexion > Sark: 4.44 + 9.9 >= 16.8
# Zexion > Scar: 4.44 + 6.34 >= 16.8
# Zexion > Sephiroth: 4.44 + 6.57 >= 16.8
# Zexion > Shan-Yu: 4.44 + 10.15 >= 16.8
# Zexion > Storm Rider: 4.44 + 9.27 >= 16.8
# Zexion > The Experiment: 4.44 + 11.7 >= 16.8
# Zexion > Vexen: 4.44 + 8.97 >= 16.8
# Zexion > Xaldin: 4.44 + 9.61 >= 16.8
# Zexion > Xemnas: 4.44 + 6.16 >= 16.8
# Zexion > Xigbar: 4.44 + 11.18 >= 16.8

# %%
# Sort bosses according to their size
for boss in sorted(bosses, key=lambda k: bosses[k]["size"]):
    print("{}-{}".format(boss, bosses[boss]["size"]))

# %%
# Sort bosses according to their size
for boss in sorted(bosses, key=lambda k: bosses[k]["roomsize"]):
    print("{}-{}".format(boss, bosses[boss]["roomsize"]))

# %%
for boss in sorted(bosses, key=lambda k: len(bosses[k]["available"])):
    print("{}-{}".format(boss, len(bosses[boss]["available"])))
# Out:
# Hydra-5
# Storm Rider-5
# Zexion-25
# Vexen-26
# Luxord-31
# Saix-32
# Demyx-33
# Lexaeus-33
# Hostile Program-34
# Roxas-43
# Larxene-45
# Xigbar-45
# Axel II-50
# Hades Cups-50
# Shan-Yu-53
# Twilight Thorn-53
# Dark Thorn-54
# Groundshaker-54
# Marluxia-54
# Prison Keeper-55
# Sephiroth-55
# Armor Xemnas I-56
# Pete TR-56
# Xaldin-56
# Xemnas-56
# Armor Xemnas II-57
# Axel I-57
# Blizzard Lord-57
# Blizzard Lord (Cups)-57
# Cerberus-57
# Cerberus (Cups)-57
# Cloud-57
# Cloud (1)-57
# Cloud (2)-57
# Grim Reaper I-57
# Hades II-57
# Hades II (1)-57
# Hercules-57
# Leon-57
# Leon (1)-57
# Leon (2)-57
# Leon (3)-57
# Past Pete-57
# Pete Cups-57
# Pete OC II-57
# Sark-57
# Scar-57
# The Experiment-57
# Tifa-57
# Tifa (1)-57
# Tifa (2)-57
# Volcano Lord-57
# Volcano Lord (Cups)-57
# Yuffie-57
# Yuffie (1)-57
# Yuffie (2)-57
# Yuffie (3)-57

# %%
    solutions = []
    start_time = time.time()
    while len(solutions) < SOLUTIONSWANTED:
        possible_solution = list(bosses_base)
        random.shuffle(possible_solution)
    
        solution_found = True
        for b in range(len(possible_solution)):
            if not possible_solution[b] in bosses[bosses_base[b]]["available"]:
                solution_found = False
                break
        
        if solution_found:
            length = int(time.time() - start_time)
            start_time = time.time()
            print(solution_found, len(solutions), "{}s".format(length))
            solutions.append({bosses_base[i]:possible_solution[i] for i in range(len(possible_solution))})    

    for i in range(len(solutions)):
        fn = os.path.join(outdir, options["name"], str(i))
        if not os.path.isdir(os.path.dirname(fn)):
            os.makedirs(os.path.dirname(fn))
        json.dump(solutions[i], open(fn, "w"))
